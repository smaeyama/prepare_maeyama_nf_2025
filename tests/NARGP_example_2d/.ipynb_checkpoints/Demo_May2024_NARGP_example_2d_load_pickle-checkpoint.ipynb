# %%
import sys
sys.path.append("../../")
from mfmodeling import NARGP, SingleGP
import pickle

# Uncomment below to use GPy implementation.
# Note that only RBF kernel is supported in the GPy implementation now.
"""
from mfmodeling.SingleGP_GPy import SingleGP
from mfmodeling import set_gpy_usage_in_nargp
set_gpy_usage_in_nargp(True)
"""

help(NARGP)
# Out:
# 2024-10-23 12:16:08.944143: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-23 12:16:09.026129: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-23 12:16:09.030111: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/smaeyama/mylib/netcdf-fortran-4.6.1-ifx/lib:/opt/intel/oneapi/tbb/2021.12/env/../lib/intel64/gcc4.8:/opt/intel/oneapi/mpi/2021.12/opt/mpi/libfabric/lib:/opt/intel/oneapi/mpi/2021.12/lib:/opt/intel/oneapi/mkl/2024.1/lib:/opt/intel/oneapi/ippcp/2021.11/lib/:/opt/intel/oneapi/ipp/2021.11/lib:/opt/intel/oneapi/dpl/2022.5/lib:/opt/intel/oneapi/dnnl/2024.1/lib:/opt/intel/oneapi/debugger/2024.1/opt/debugger/lib:/opt/intel/oneapi/dal/2024.2/lib:/opt/intel/oneapi/compiler/2024.1/opt/oclfpga/host/linux64/lib:/opt/intel/oneapi/compiler/2024.1/opt/compiler/lib:/opt/intel/oneapi/compiler/2024.1/lib:/opt/intel/oneapi/ccl/2021.12/lib/
# 2024-10-23 12:16:09.030124: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-10-23 12:16:09.046181: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-23 12:16:09.427591: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/smaeyama/mylib/netcdf-fortran-4.6.1-ifx/lib:/opt/intel/oneapi/tbb/2021.12/env/../lib/intel64/gcc4.8:/opt/intel/oneapi/mpi/2021.12/opt/mpi/libfabric/lib:/opt/intel/oneapi/mpi/2021.12/lib:/opt/intel/oneapi/mkl/2024.1/lib:/opt/intel/oneapi/ippcp/2021.11/lib/:/opt/intel/oneapi/ipp/2021.11/lib:/opt/intel/oneapi/dpl/2022.5/lib:/opt/intel/oneapi/dnnl/2024.1/lib:/opt/intel/oneapi/debugger/2024.1/opt/debugger/lib:/opt/intel/oneapi/dal/2024.2/lib:/opt/intel/oneapi/compiler/2024.1/opt/oclfpga/host/linux64/lib:/opt/intel/oneapi/compiler/2024.1/opt/compiler/lib:/opt/intel/oneapi/compiler/2024.1/lib:/opt/intel/oneapi/ccl/2021.12/lib/
# 2024-10-23 12:16:09.427686: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/smaeyama/mylib/netcdf-fortran-4.6.1-ifx/lib:/opt/intel/oneapi/tbb/2021.12/env/../lib/intel64/gcc4.8:/opt/intel/oneapi/mpi/2021.12/opt/mpi/libfabric/lib:/opt/intel/oneapi/mpi/2021.12/lib:/opt/intel/oneapi/mkl/2024.1/lib:/opt/intel/oneapi/ippcp/2021.11/lib/:/opt/intel/oneapi/ipp/2021.11/lib:/opt/intel/oneapi/dpl/2022.5/lib:/opt/intel/oneapi/dnnl/2024.1/lib:/opt/intel/oneapi/debugger/2024.1/opt/debugger/lib:/opt/intel/oneapi/dal/2024.2/lib:/opt/intel/oneapi/compiler/2024.1/opt/oclfpga/host/linux64/lib:/opt/intel/oneapi/compiler/2024.1/opt/compiler/lib:/opt/intel/oneapi/compiler/2024.1/lib:/opt/intel/oneapi/ccl/2021.12/lib/
# 2024-10-23 12:16:09.427691: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Help on class NARGP in module mfmodeling.NARGP:
#
# class NARGP(builtins.object)
#  |  NARGP(*args, **kwargs)
#  |
#  |  Nonlinear autoregressive multi-fidelity Gaussian process regression (NARGP).
#  |  P. Perdikaris, et al., "Nonlinear information fusion algorithms for data-efficient multi-fidelity modeling"
#  |  Proc. R. Soc. A 473, 20160751 (2017). http://dx.doi.org/10.1098/rspa.2016.0751
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, *args, **kwargs)
#  |      Parameters
#  |      ----------
#  |      data_list : list[nfidelity]
#  |          List of multi-fidelity training data of y=f(x), where input x and output y are vectors.
#  |
#  |          Structure of the list of data is as follow.
#  |          data_list[ 0] = [data_input_lowest[nsample_lowest,ninput],   data_output_lowest[nsample_lowest,noutput_lowest]]
#  |          data_list[ 1] = [data_input_1st[nsample_1st,ninput],         data_output_1st[nsample_1st,noutput_1st]]
#  |          ...
#  |          data_list[-1] = [data_input_highest[nsample_highest,ninput], data_output_highest[nsample_highest,noutput_highest]]
#  |
#  |          "ninput" (dimension of the input vector x) is the same for all fidelities, while "noutput_***" (dimension of
#  |          the output vector y) and "nsample_***" (number of sampling of data set) can be different for each fidelity.
#  |      single_gp_config_list : list[dict]
#  |          List of dictionaries containing the arguments for each SingleGP class constructor.
#  |          single_gp_config_list[i] contains the arguments for i-th fidelity data.
#  |      normalize : Bool
#  |          Options for normalizing input data list.
#  |
#  |  optimize(self, **kwargs)
#  |      Optimization of the hyperparameters in NARGP.
#  |
#  |      Parameters
#  |      ----------
#  |      optimize_restarts : Int
#  |          Number of iterations in the optimize_restart method.
#  |      max_iters : Int
#  |          Maximum number of iterations in the optimization algorithm.
#  |      optimizer_name : Str
#  |          TensorFlow optimizer name. Either "Scipy" and "Adam", which use
#  |          gpflow.optimizer.Scipy and tf.optimizer.Adam, respectively,
#  |          are available. Default to "Scipy".
#  |      optimizer_parameters: Dict
#  |          Optional detailed optimization settings.
#  |      nMonteCarlo : Int
#  |          Number of Monte Carlo sampling points for prediction called in NARGP.
#  |      verbose : Bool
#  |          Shows progress of the __optimize_restart if True.
#  |      plot_history : Bool
#  |          Shows history of the objective function in the __optimize_restart if True.
#  |      optimize_noise_in_first_step : Bool
#  |          Optimize noise level in the first step if True.
#  |      use_built_in_initialization : Bool
#  |          Use hyper parameter initialization method (if any) of the kernel.
#  |
#  |  predict(self, x, ifidelity=None, nMonteCarlo=1000, called_in_optimize=False)
#  |      Parameters
#  |      ----------
#  |      x : Numpy.ndarray[..., ninput]
#  |          The points at which to make a prediction
#  |      ifidelity : Int
#  |          0 < ifidelity < nfidelity-1
#  |          Prediction for the specified fidelity model
#  |      nMonteCarlo : Int
#  |          Sampling number of Monte Carlo integration of Eq. (2.14)
#  |      called_in_optimize : Bool
#  |
#  |
#  |      Returns
#  |      -------
#  |      mean : Numpy.ndarray[..., noutput]
#  |          Mean for i-fidelity model
#  |      variance : Numpy.ndarray[..., noutput]
#  |          Variance for i-th fidelity model
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  data_list
#  |
#  |  kernel_list
#  |
#  |  model_list
#  |
#  |  single_gp_list
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# ### Preparation of data set

# %%
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt

np.random.seed(11)
tf.random.set_seed(11)

def high(x):
    '''
    Exact Branin function f_3
    '''
    x1 = x[...,0]
    x2 = x[...,1]
    return (-1.275*x1**2 / np.pi**2 + 5.0*x1/np.pi + x2 - 6.0)**2 + (10.0 - 5.0/(4.0*np.pi))*np.cos(x1) + 10.0

def medium(x):
    '''
    Medium-fidelity function f_2
    P. Perdikaris, et al., "Nonlinear information fusion algorithms for data-efficient multi-fidelity modeling"
    Proc. R. Soc. A 473, 20160751 (2017). http://dx.doi.org/10.1098/rspa.2016.0751
    '''
    x1 = x[...,0]
    x2 = x[...,1]
    return 10.0*np.sqrt(high(x-2.0)) + 2.0*(x1-0.5)-3.0*(3.0*x2-1.0) - 1.0

def low(x):
    '''
    Low-fidelity function f_2
    P. Perdikaris, et al., "Nonlinear information fusion algorithms for data-efficient multi-fidelity modeling"
    Proc. R. Soc. A 473, 20160751 (2017). http://dx.doi.org/10.1098/rspa.2016.0751
    '''
    x1 = x[...,0]
    x2 = x[...,1]
    return medium(1.2*(x+2.0)) - 3.0*x2 + 1.0

def scale_range(x,ub,lb):
    Np = x.shape[0]
    dim = x.shape[1]
    for i in range(0,Np):
        for j in range(0,dim):
            tmp = ub[j] -lb[j]
            x[i][j] = tmp*x[i][j] + lb[j]
    return x

def rmse(pred, truth):
    pred = pred.flatten()
    truth = truth.flatten()
    return np.sqrt(np.mean((pred-truth)**2))


nlow = 80
w0 = -5 + 15*np.random.rand(nlow)
w1 = 15 * np.random.rand(nlow)
data_low_x = np.stack([w0,w1],axis=-1)
data_low_y = low(data_low_x)

nmed = 40
perm = np.random.permutation(nlow)
data_med_x = data_low_x[perm[0:nmed],:]

# data_restrict = data_med_x[data_med_x[:,0]<5]
data_restrict = data_med_x[data_med_x[:,1]<10]
nhigh = 20
if data_restrict.shape[0] < nhigh:
    print("Data points in the restricted region is too small")
else:
    perm = np.random.permutation(data_restrict.shape[0])
    data_high_x = data_restrict[perm[0:nhigh],:]

# %%
fig = plt.figure(figsize=(4,4))
ax = fig.add_subplot()
ax.plot(data_low_x[:,0],data_low_x[:,1],"+",label=r"Low-fidelity $x$")
ax.plot(data_med_x[:,0],data_med_x[:,1],"x",label=r"Medium-fidelity $x$")
ax.plot(data_high_x[:,0],data_high_x[:,1],".",label=r"High-fidelity $x$")
ax.set_xlabel(r"$x_1$")
ax.set_ylabel(r"$x_2$")
ax.set_xlim(-5,10)
ax.set_ylim(0,15)
ax.legend(loc="lower left", bbox_to_anchor=(1,0))
plt.show()

# %%
# 推定に用いる入力データ: Low, medium, high-fidelity dataset
data_low_y = low(data_low_x)
data_med_y = medium(data_med_x)
data_high_y = high(data_high_x)

# データセットの描画
# %matplotlib inline
# %matplotlib qt
x0 = np.linspace(-5,10,20)
x1 = np.linspace(0,15,20)
x0m, x1m = np.meshgrid(x0,x1)
xm = np.stack([x0m,x1m],axis=-1)

fig = plt.figure()
ax = fig.add_subplot(projection="3d")
ax.plot_wireframe(x0m,x1m,high(xm),lw=0.5,color="black",label="High-fidelity function")
ax.plot(data_high_x[:,0],data_high_x[:,1],data_high_y,"*",label="Input data for GP")
ax.set_xlabel(r"x_0")
ax.set_ylabel(r"x_1")
ax.set_zlim(-100,300)
ax.view_init(30,-150)
ax.legend()
plt.show()

fig = plt.figure()
ax = fig.add_subplot(projection="3d")
ax.plot_wireframe(x0m,x1m,medium(xm),lw=0.5,color="black",label="Medium-fidelity function")
ax.plot(data_med_x[:,0],data_med_x[:,1],data_med_y,"*",label="Input data for GP")
ax.set_xlabel(r"x_0")
ax.set_ylabel(r"x_1")
ax.set_zlim(-100,300)
ax.view_init(30,-150)
ax.legend()
plt.show()

fig = plt.figure()
ax = fig.add_subplot(projection="3d")
ax.plot_wireframe(x0m,x1m,low(xm),lw=0.5,color="black",label="Low-fidelity function")
ax.plot(data_low_x[:,0],data_low_x[:,1],data_low_y,"*",label="Input data for GP")
ax.set_xlabel(r"x_0")
ax.set_ylabel(r"x_1")
ax.set_zlim(-100,300)
ax.view_init(30,-150)
ax.legend()
plt.show()

# %% [markdown]
# ### Nonlinear autoregressive multi-fidelity Gaussian process regression (NARGP)

# %%
# Set kernel name to use
# KERNEL_NAME = "RBF"
# KERNEL_NAME = "SpectralMixture"
KERNEL_NAME = "NeuralKernelNetwork"

data_list = [[data_low_x,data_low_y[:,None]],
             [data_med_x,data_med_y[:,None]],
             [data_high_x,data_high_y[:,None]]]
single_gp_config_list = [
    {"kernel": KERNEL_NAME},
    {"kernel": KERNEL_NAME},
    {"kernel": KERNEL_NAME},
]

# Uncomment the following to use different kernel for different fidelity data.
# However, if GPy implementation are being used,
# Spectral Mixture Kernel and Neural Kernel Network are not implemented,
# so RBF will be used.

# Different kernel for each fidelity
#single_gp_config_list = [
#    {"kernel": "RBF"},
#    {"kernel": "SpectralMixture"},
#    {"kernel": "NeuralKernelNetwork"},
#]

# Different initialization for each fidelity
#single_gp_config_list = [
#    {"kernel": "RBF", "kernel_args": {"lengthscales": [1.0, 1.0]}},
#    {"kernel": "RBF", "kernel_args": {"lengthscales": [2.0, 2.0]}},
#    {"kernel": "RBF", "kernel_args": {"lengthscales": [3.0, 3.0]}},
#]

model_nargp = NARGP(
    data_list = data_list,
    single_gp_config_list=single_gp_config_list,
    normalize=True)
from time import time as timer
t1=timer()
model_nargp.optimize(optimize_restarts=10, nMonteCarlo=1000, verbose=True)
t2=timer(); print(t2-t1, xm.size)


if KERNEL_NAME == "RBF":
    with open("model_NARGP_RBF.pkl","wb") as f:
        pickle.dump(model_nargp,f)
elif KERNEL_NAME == "SpectralMixture":
    with open("model_NARGP_SMK.pkl","wb") as f:
        pickle.dump(model_nargp,f)
elif KERNEL_NAME == "NeuralKernelNetwork":
    with open("model_NARGP_NKN.pkl","wb") as f:
        pickle.dump(model_nargp,f)


if KERNEL_NAME == "RBF":
    with open("model_NARGP_RBF.pkl","rb") as f:
        model_nargp = pickle.load(f)
elif KERNEL_NAME == "SpectralMixture":
    with open("model_NARGP_SMK.pkl","rb") as f:
        model_nargp = pickle.load(f)
elif KERNEL_NAME == "NeuralKernelNetwork":
    with open("model_NARGP_NKN.pkl","rb") as f:
        model_nargp = pickle.load(f)



t1=timer()
mean, var = model_nargp.predict(xm.reshape(xm.size//2,2),nMonteCarlo=100)
t2=timer(); print(t2-t1, xm.size)
# Out:
# NARGP is using GPflow.
# nfidelity= 3 , optimize_restarts= 10 , max_iters= 400
# optimize_restarts= 10 , max_iters= 400
# 2024-10-23 12:16:11.835019: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/smaeyama/mylib/netcdf-fortran-4.6.1-ifx/lib:/opt/intel/oneapi/tbb/2021.12/env/../lib/intel64/gcc4.8:/opt/intel/oneapi/mpi/2021.12/opt/mpi/libfabric/lib:/opt/intel/oneapi/mpi/2021.12/lib:/opt/intel/oneapi/mkl/2024.1/lib:/opt/intel/oneapi/ippcp/2021.11/lib/:/opt/intel/oneapi/ipp/2021.11/lib:/opt/intel/oneapi/dpl/2022.5/lib:/opt/intel/oneapi/dnnl/2024.1/lib:/opt/intel/oneapi/debugger/2024.1/opt/debugger/lib:/opt/intel/oneapi/dal/2024.2/lib:/opt/intel/oneapi/compiler/2024.1/opt/oclfpga/host/linux64/lib:/opt/intel/oneapi/compiler/2024.1/opt/compiler/lib:/opt/intel/oneapi/compiler/2024.1/lib:/opt/intel/oneapi/ccl/2021.12/lib/
# 2024-10-23 12:16:11.835106: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2024-10-23 12:16:11.835144: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (VAIO-smae): /proc/driver/nvidia/version does not exist
# 2024-10-23 12:16:11.835630: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Optimization restart 1/10,  f =  -106.4946563074224
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                                              </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[1].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>42.81665                                           </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[1].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[121.57363 123.47103]                              </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[7].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.036094816795184e-28                              </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[7].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.88499864 0.04521586]                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.493622121303824e-15                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[1].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[139.77781 191.46471]                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>4.963835681810753e-51                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[  0.96212646 140.31205   ]                        </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.1357014518164608e-20                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[ 27.02309 114.8306 ]                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>31.38873                                           </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[4].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.00013339937967699056                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.01618687797631507                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.98998759 4.09535   ]                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>127.92698                                          </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>5.1900615765179813e-05                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.28876529 1.88651   ]                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[7].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.67117104 0.41357121]                            </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[0]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8, 8) </td><td>float64</td><td>[[6.86730031e-17, 1.23283350e+02, 2.12968081e-11...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[1]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8,)   </td><td>float64</td><td>[0.03819866, 0.00358204, 0.01786711...             </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[2]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4, 4) </td><td>float64</td><td>[[1.79046100e+01, 8.81435782e-10, 2.58978480e-10...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[3]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4,)   </td><td>float64</td><td>[0.01793243, 0.01510336, 0.0157026...              </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[4]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1, 2) </td><td>float64</td><td>[[6.53021470e-15 5.06990487e-08]]                  </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[5]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[9.5335903e-10]                                    </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>4.7790399236284035e-05                             </td></tr>
# </tbody>
# </table>
# Optimization restart 2/10,  f =  -104.98525268100668
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                                              </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[1].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>40.14872                                           </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[1].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[ 8.37578 18.06153]                                </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[7].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.036094816795184e-28                              </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[7].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.02911656 0.10401264]                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>9.69472                                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[1].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[9.40735    0.00957465]                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>13.695                                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.37772801 2.86381   ]                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>5.02239                                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[4.89936 7.91492]                                  </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>5.533940641859317e-09                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[4].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>8.76619                                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>14.88231                                           </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[6.79074587e-06 2.52164800e+01]                    </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>6.004489208489888e-12                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.00017472056653610441                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.40338294 9.90531   ]                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[7].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.54249002 0.99061056]                            </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[0]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8, 8) </td><td>float64</td><td>[[1.24544883e-03, 1.67100894e-07, 1.08845012e-01...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[1]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8,)   </td><td>float64</td><td>[0.01654757, 0.01822292, 0.01466715...             </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[2]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4, 4) </td><td>float64</td><td>[[6.78012892e-04, 2.15896986e-02, 6.06929301e-05...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[3]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4,)   </td><td>float64</td><td>[0.02155437, 0.02552364, 0.02094391...             </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[4]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1, 2) </td><td>float64</td><td>[[1.87170301e-11 1.32605924e-09]]                  </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[5]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[4.30887228e-05]                                   </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>4.794714728381834e-05                              </td></tr>
# </tbody>
# </table>
# Optimization restart 3/10,  f =  -105.49994853093581
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                                              </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[1].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>39.62031                                           </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[1].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[44.17718 17.51207]                                </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[7].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.036094816795184e-28                              </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[7].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.85647334 0.59657559]                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>4.01611                                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[1].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[1.32927236e-02 2.05721200e+01]                    </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.9661021319574724e-05                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[ 1.04845 15.025  ]                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.0007030703657237079                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[6.05763 3.46209]                                  </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>6.604975749527158e-06                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[4].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.42073                                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>8.91595                                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[1.47925 9.67221]                                  </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.08673597541836542                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.969427416775538e-12                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.44816835 0.099713  ]                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[7].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.9106375 0.4369853]                              </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[0]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8, 8) </td><td>float64</td><td>[[1.16720891e-02, 5.56212784e-03, 2.41585417e-02...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[1]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8,)   </td><td>float64</td><td>[0.01213428, 0.01221107, 0.01180038...             </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[2]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4, 4) </td><td>float64</td><td>[[0.02053882, 0.00486438, 0.02983123...            </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[3]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4,)   </td><td>float64</td><td>[0.01985959, 0.01783723, 0.01390137...             </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[4]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1, 2) </td><td>float64</td><td>[[1.08937806e-06 1.39897115e-03]]                  </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[5]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[0.00173882]                                       </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>2.1094165425142573e-05                             </td></tr>
# </tbody>
# </table>
# Optimization restart 4/10,  f =  -99.32227789921032
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                                              </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[1].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>38.21428                                           </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[1].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[165.02213  65.96901]                              </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[7].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.036094816795184e-28                              </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[7].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.17334253 0.70695227]                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>8.25346                                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[1].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[6.61214481e-02 1.23292150e+02]                    </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.14581470337436353                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[ 0.16908531 13.0485    ]                          </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.20981570381566697                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[ 9.04854 43.00689]                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>10.11965                                           </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[4].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>8.92761                                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>4.2338064841382436e-17                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[ 3.23056 47.09375]                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>5.664799633837419e-15                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>23.80556                                           </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.61827098 3.34484   ]                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[7].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.45034671 0.70868434]                            </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[0]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8, 8) </td><td>float64</td><td>[[3.21811450e-04, 3.51205806e-07, 3.13974500e-02...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[1]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8,)   </td><td>float64</td><td>[0.01410466, 0.01316349, 0.02143461...             </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[2]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4, 4) </td><td>float64</td><td>[[1.78475619e-04, 1.26259406e-03, 5.94409676e-04...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[3]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4,)   </td><td>float64</td><td>[0.04986178, 0.03440241, 0.03078867...             </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[4]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1, 2) </td><td>float64</td><td>[[1.17493108e-07 1.97804331e-12]]                  </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[5]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[1.35254623e-08]                                   </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1e-06                                              </td></tr>
# </tbody>
# </table>
# Optimization restart 5/10,  f =  -108.96054972152103
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                                              </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[1].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>39.21061                                           </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[1].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[15.7246  34.63456]                                </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[7].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.036094816795184e-28                              </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[7].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.76499323 0.22551612]                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.00022607000296444795                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[1].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[39.0656  72.28403]                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.275445975798038e-05                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[9.72333 7.3879 ]                                  </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.95224                                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.66027448 4.87037   ]                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.43233711840217987                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[4].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.43605                                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.696083426768481                                  </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[ 7.42599 13.7528 ]                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.5614648833864814                                 </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>4.9651203982586334e-29                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.01327762 0.09783209]                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[7].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.06328965 0.93328688]                            </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[0]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8, 8) </td><td>float64</td><td>[[1.76634391e-05, 3.05444300e+01, 3.59497146e-02...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[1]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8,)   </td><td>float64</td><td>[1.60198005e-02, 7.82695187e-05, 2.35912967e-02... </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[2]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4, 4) </td><td>float64</td><td>[[4.83067000e+00, 2.45374881e-06, 6.91210749e-04...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[3]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4,)   </td><td>float64</td><td>[0.01242264, 0.01329322, 0.01477602...             </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[4]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1, 2) </td><td>float64</td><td>[[6.20011630e-10 8.55607753e-11]]                  </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[5]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[1.17908271e-06]                                   </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.591089256377399e-05                              </td></tr>
# </tbody>
# </table>
# Optimization restart 6/10,  f =  -105.6653607623293
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                                              </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[1].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>39.99798                                           </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[1].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[12.72054 60.11713]                                </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[7].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.036094816795184e-28                              </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[7].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.72791055 0.93098824]                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.3300756856646262                                 </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[1].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[18.86825 52.37129]                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.5456427164294857e-18                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[ 1.66495 14.6733 ]                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>14.23561                                           </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.57308523 3.59319   ]                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.8641833830374044                                 </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[4].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.3536565522054511                                 </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.968144229193202e-06                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[ 5.32275 21.24326]                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.026387645625072745                               </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.040328578929470074                               </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[51.74585 24.12452]                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[7].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.31892819 0.13057795]                            </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[0]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8, 8) </td><td>float64</td><td>[[6.51901910e-05, 8.30385395e-03, 1.57900810e-03...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[1]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8,)   </td><td>float64</td><td>[0.01197041, 0.01188024, 0.01181029...             </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[2]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4, 4) </td><td>float64</td><td>[[0.00338863, 0.00148106, 0.08078074...            </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[3]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4,)   </td><td>float64</td><td>[0.01228486, 0.01216532, 0.0145005...              </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[4]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1, 2) </td><td>float64</td><td>[[1.21133850e-07 2.36716994e-07]]                  </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[5]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[0.00091886]                                       </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>4.4883498349761126e-05                             </td></tr>
# </tbody>
# </table>
# Optimization restart 7/10,  f =  -107.47569058950575
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                                              </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[1].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>38.37814                                           </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[1].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[41.92104 40.25472]                                </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[7].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.036094816795184e-28                              </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[7].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.12062697 0.23662888]                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.05032589420314123                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[1].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.05865038 8.50261   ]                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>2.160973548926e-08                                 </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[ 0.97572495 11.60327   ]                          </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>17.53154                                           </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[ 1.68583 11.65436]                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.07220893073048479                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[4].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.02234109858447112                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.5830233926361597                                 </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[ 0.07051864 16.75884   ]                          </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.00014466941458380982                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>2.9391652441271704e-06                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[19.09546  5.52058]                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[7].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.32636565 0.4282287 ]                            </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[0]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8, 8) </td><td>float64</td><td>[[2.26136070e-02, 3.51764108e-05, 4.39827405e-03...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[1]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8,)   </td><td>float64</td><td>[0.01291321, 0.01275502, 0.01227753...             </td></tr>
# ...
# <tr><td>GPR.kernel.kernels[0].kernels[0].primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel.kernels[0].kernels[0]._primitive_kernels[7].base_kernel.lengthscales                                                                    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[ 85.35828 128.54664]                                 </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.0                                                   </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[1].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[117.3023  131.53666]                                 </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[2].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.0686984194526416e-127                               </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[2].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[3.08840531e-27 9.67146200e+01]                       </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[3].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>8.965468378209526e-198                                </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[3].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[7.11505372e-06 1.42245580e+02]                       </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[3].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.5288444822760857e-29                                </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[4].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.0                                                   </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[5].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.331091240331302e-239                                </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[5].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[5.28997195e-05 4.66257300e+01]                       </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[5].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>9.08348                                               </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[6].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.3225302578915546e-223                               </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[6].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[ 47.65636 303.23535]                                 </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[7].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[181.97523  49.52571]                                 </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._nkn_parameters[0]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8, 8) </td><td>float64</td><td>[[1.59892829e-59, 1.63822839e-33, 9.21025868e-30...   </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._nkn_parameters[1]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8,)   </td><td>float64</td><td>[6.73196526e-091, 3.11960154e-106, 2.61298554e-059... </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._nkn_parameters[2]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4, 4) </td><td>float64</td><td>[[5.41326709e-248, 3.41611843e-125, 2.44367837e-152...</td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._nkn_parameters[3]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4,)   </td><td>float64</td><td>[4.80502260e-31, 4.41284824e-23, 2.53528300e+01...    </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._nkn_parameters[4]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1, 2) </td><td>float64</td><td>[[0.00000000e+00 2.82860089e-74]]                     </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._nkn_parameters[5]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[1.07391516e-71]                                      </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel.kernels[0].kernels[1]._primitive_kernels[1].base_kernel.variance                                                                    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.0                                                   </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel.kernels[0].kernels[1]._primitive_kernels[1].base_kernel.lengthscales                                                                    </td
# Optimization restart 10/10,  f =  20.640792323210796
# <table>
# <thead>
# <tr><th>name                                                               </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                                              </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.kernels[0].kernels[0].primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel.kernels[0].kernels[0]._primitive_kernels[1].base_kernel.variance                                                                    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.005592109321735204                               </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0].primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel.kernels[0].kernels[0]._primitive_kernels[1].base_kernel.lengthscales                                                                    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.57484421 0.69395101]                            </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0].primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel.kernels[0].kernels[0]._primitive_kernels[7].base_kernel.variance                                                                    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.0063165654374332915                              </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0].primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel.kernels[0].kernels[0]._primitive_kernels[7].base_kernel.lengthscales                                                                    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.56468596 1.09969   ]                            </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.5890917520783588e-05                             </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[1].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.41273795 0.08933522]                            </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[2].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.031183874657062682                               </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[2].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.58224822 0.53502013]                            </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[3].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.0008755647709594697                              </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[3].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.30003786 0.06215273]                            </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[3].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.5141143019287151                                 </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[4].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>2.4089314732801608e-05                             </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[5].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>9.03708594906979e-06                               </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[5].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.67190928 0.14912395]                            </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[5].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.20936929223649375                                </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[6].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.003661189780561165                               </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[6].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.46180748 1.61967   ]                            </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._primitive_kernels[7].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[7.89534586e-05 3.41926397e-01]                    </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._nkn_parameters[0]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8, 8) </td><td>float64</td><td>[[0.51797706, 0.07878605, 0.58482117...            </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._nkn_parameters[1]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8,)   </td><td>float64</td><td>[0.3454287, 0.11212909, 0.08582704...              </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._nkn_parameters[2]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4, 4) </td><td>float64</td><td>[[0.04479072, 0.0033196, 0.02343121...             </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._nkn_parameters[3]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4,)   </td><td>float64</td><td>[0.41720707, 0.04272452, 0.48593896...             </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._nkn_parameters[4]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1, 2) </td><td>float64</td><td>[[5.72109660e-08 5.60699599e-04]]                  </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0]._nkn_parameters[5]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[1.89454966e-31]                                   </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel.kernels[0].kernels[1]._primitive_kernels[1].base_kernel.variance                                                                    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.0002021403156134376                              </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel.kernels[0].kernels[1]._primitive_kernels[1].base_kernel.lengthscales                                                                    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </t
# 160.33739733695984 800
# WARNING:tensorflow:5 out of the last 5 calls to <function NeuralKernelNetwork.K_diag at 0x7fac21fd6170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function NeuralKernelNetwork.K_diag at 0x7fac6452c040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 38.843616008758545 800

# %% [markdown]
# ### Single GP using only high-fidelity data (for comparison)

# %%
data = [data_high_x,data_high_y[:,None]]
model_singlegp = SingleGP(data = data, kernel=KERNEL_NAME, normalize=True)
model_singlegp.optimize(optimize_restarts=10, verbose=True)


if KERNEL_NAME == "RBF":
    with open("model_singleGP_RBF.pkl","wb") as f:
        pickle.dump(model_singlegp,f)
elif KERNEL_NAME == "SpectralMixture":
    with open("model_singleGP_SMK.pkl","wb") as f:
        pickle.dump(model_singlegp,f)
elif KERNEL_NAME == "NeuralKernelNetwork":
    with open("model_singleGP_NKN.pkl","wb") as f:
        pickle.dump(model_singlegp,f)


if KERNEL_NAME == "RBF":
    with open("model_singleGP_RBF.pkl","rb") as f:
        model_singlegp = pickle.load(f)
elif KERNEL_NAME == "SpectralMixture":
    with open("model_singleGP_SMK.pkl","rb") as f:
        model_singlegp = pickle.load(f)
elif KERNEL_NAME == "NeuralKernelNetwork":
    with open("model_singleGP_NKN.pkl","rb") as f:
        model_singlegp = pickle.load(f)


mean_singlegp, var_singlegp = model_singlegp.predict(xm.reshape(xm.size//2,2))
# Out:
# optimize_restarts= 10 , max_iters= 400
# Optimization restart 1/10,  f =  -6.166939412754218
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                                              </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[1].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>99.69265                                           </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[1].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[6.43191829e-03 8.74784440e+02]                    </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[7].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>7.736815584360358e-296                             </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[7].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.87697622 0.65720542]                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>97.29092                                           </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[1].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[7.4400114e+02 1.5208054e-01]                      </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>2.5975083699442655e-114                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[521.17375 259.6566 ]                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>8.914955237154239e-178                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[2.8055900e-03 3.4266122e+02]                      </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>5.042284664764779e-113                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[4].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>103.6324                                           </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.4045021697695098e-60                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[105.45589 298.99907]                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.0320233848858066e-18                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.331898180364232e-279                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[  4.952   373.13403]                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[7].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[1.07471    0.18312731]                            </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[0]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8, 8) </td><td>float64</td><td>[[4.63808070e-44, 1.79412100e+02, 1.31698456e-13...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[1]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8,)   </td><td>float64</td><td>[0.34936894, 0.30333262, 0.04678394...             </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[2]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4, 4) </td><td>float64</td><td>[[7.91503725e-30, 3.24019476e-41, 4.03048067e-45...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[3]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4,)   </td><td>float64</td><td>[0.22365641, 0.30266379, 0.62964509...             </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[4]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1, 2) </td><td>float64</td><td>[[4.17500388e-131 1.47075287e-021]]                </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[5]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[450.03901]                                        </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1e-06                                              </td></tr>
# </tbody>
# </table>
# Optimization restart 2/10,  f =  -4.7022357755209505
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                                                 </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[1].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>127.41958                                             </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[1].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[   2.48199 1754.31954]                               </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[7].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>7.736815584360358e-296                                </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[7].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.34748517 0.37158059]                               </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.0444297301801102e-294                               </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[1].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[1.51532    0.09750008]                               </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>5.914104327576709e-168                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[3.24410789e-10 4.69077820e+02]                       </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.8456853847171463e-98                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[ 64.90291 487.96736]                                 </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>34.45604                                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[4].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>9.480115122204199e-11                                 </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.1854424792876074e-185                               </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[549.01026 271.84006]                                 </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>6.98121202244222e-79                                  </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.0                                                   </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[6935.70151  335.09022]                               </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[7].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.89090114 0.063813  ]                               </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[0]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8, 8) </td><td>float64</td><td>[[7.48014380e+002, 1.83549017e-009, 1.74299645e-025...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[1]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8,)   </td><td>float64</td><td>[0., 0.01409052, 0.14197059...                        </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[2]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4, 4) </td><td>float64</td><td>[[9.02045730e+002, 1.81852072e-188, 4.60114530e-183...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[3]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4,)   </td><td>float64</td><td>[0.00269914, 0.00158083, 0.00187216...                </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[4]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1, 2) </td><td>float64</td><td>[[6.81544665e-05 0.00000000e+00]]                     </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[5]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[0.]                                                  </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1e-06                                                 </td></tr>
# </tbody>
# </table>
# Optimization restart 3/10,  f =  -13.29068075589463
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                                                 </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[1].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>160.80998                                             </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[1].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[1.24465575e-02 1.26001464e+03]                       </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[7].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>7.736815584360358e-296                                </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[7].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.57922794 0.52953906]                               </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>5.17078                                               </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[1].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[2.7988565e+02 9.7076518e-02]                         </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>312.89581                                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[162.5304  640.36541]                                 </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>6.944784960330823e-83                                 </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[114.62378 554.68737]                                 </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>2.0902364954225879e-38                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[4].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>21.5507                                               </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>32.23216                                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[403.79022 532.98298]                                 </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>145.38105                                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.0                                                   </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[181.26385 209.36976]                                 </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[7].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.70911292 0.26014251]                               </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[0]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8, 8) </td><td>float64</td><td>[[7.04701228e-020, 9.16274546e-136, 3.92871129e-015...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[1]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8,)   </td><td>float64</td><td>[0.18568823, 0.06278964, 0.57347458...                </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[2]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4, 4) </td><td>float64</td><td>[[9.56234493e-126, 1.45578000e+000, 1.62625000e+000...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[3]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4,)   </td><td>float64</td><td>[18.26561, 12.65579, 3.25789...                       </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[4]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1, 2) </td><td>float64</td><td>[[5.08869028e-111 1.19351099e-022]]                   </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[5]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[679.7193]                                            </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1e-06                                                 </td></tr>
# </tbody>
# </table>
# Optimization restart 4/10,  f =  21.71646373156058
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[1].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>160.66351                              </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[1].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.98654947 1.83734   ]                </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[7].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>7.736815584360358e-296                 </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[7].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.43421822 0.87737244]                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.8281184076639233                     </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[1].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[2.43693565e-04 6.45724000e+00]        </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.9327001541710278                     </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.91148895 1.11061   ]                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.8962537002495747                     </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.23064103 0.12798904]                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.19106560050772628                    </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[4].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.8309102938819318                     </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.9305049801470731                     </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.62699052 0.52514544]                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.09753394775435141                    </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.8867541701939254                     </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[1.00875    0.38442116]                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[7].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[1.15463    0.32931678]                </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[0]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8, 8) </td><td>float64</td><td>[[0.06513935, 0.01204842, 0.0923391... </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[1]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8,)   </td><td>float64</td><td>[0.00998871, 0.00998955, 0.00998653... </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[2]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4, 4) </td><td>float64</td><td>[[0.11818922, 0.11119173, 0.15564983...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[3]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4,)   </td><td>float64</td><td>[0.00999965, 0.00999958, 0.00999936... </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[4]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1, 2) </td><td>float64</td><td>[[0.03774232 0.01443463]]              </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[5]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[0.01]                                 </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.003716844107348013                   </td></tr>
# </tbody>
# </table>
# Optimization restart 5/10,  f =  -19.13593313480313
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                                                 </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[1].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>164.67112                                             </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[1].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[1.09875508e-01 9.16800590e+02]                       </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[7].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>7.736815584360358e-296                                </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[7].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.90185968 0.96859684]                               </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>63.17096                                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[1].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[275.93593 403.81089]                                 </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>2.2428                                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[  0.72322156 342.00525   ]                           </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>5.099645889671461e-214                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[  0.40482395 229.8945    ]                           </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>6.398382254245872e-161                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[4].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>54.62147                                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.3272454494638679e-36                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[ 38.89443 206.67314]                                 </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>28.67915                                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>6.908557470817252e-56                                 </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[ 32.94656 374.94045]                                 </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[7].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.87822869 0.40238127]                               </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[0]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8, 8) </td><td>float64</td><td>[[7.37559661e-006, 6.68876137e-020, 9.71352196e-008...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[1]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8,)   </td><td>float64</td><td>[0.0191899, 0.0168435, 0.02617936...                  </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[2]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4, 4) </td><td>float64</td><td>[[3.14784867e-17, 5.64744395e-17, 3.51262600e+01...   </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[3]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4,)   </td><td>float64</td><td>[0.05637494, 0.03576725, 0.11404061...                </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[4]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1, 2) </td><td>float64</td><td>[[1.74606494e-17 1.26814800e-66]]                     </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[5]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[5.4530135e-13]                                       </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1e-06                                                 </td></tr>
# </tbody>
# </table>
# Optimization restart 6/10,  f =  7.242157769813495
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                                              </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[1].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>163.87737                                          </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[1].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[2.20735    0.17165285]                            </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[7].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>7.736815584360358e-296                             </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[7].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.10741715 0.37396433]                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>22.96936                                           </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[1].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[ 0.19740296 97.53705   ]                          </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.398415612365899e-18                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[13.82933 95.2646 ]                                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>4.540341080421121e-40                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[7.3989681e-02 8.3863440e+01]                      </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.5789462581958012e-27                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[4].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>9.38086                                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>4.4061330433955123e-23                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[ 0.83457071 60.94297   ]                          </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>2.9397968780667057e-16                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>4.1284457827365448e-22                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[  0.87205689 114.06331   ]                        </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[7].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.20078513 0.06479385]                            </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[0]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8, 8) </td><td>float64</td><td>[[9.35448071e-04, 2.84235075e-10, 1.04131878e-03...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[1]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8,)   </td><td>float64</td><td>[0.01024754, 0.01051716, 0.00928316...             </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[2]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4, 4) </td><td>float64</td><td>[[1.89270957e-07, 1.59070083e-08, 7.94985553e-09...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[3]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4,)   </td><td>float64</td><td>[0.01201059, 0.01277829, 0.00928621...             </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[4]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1, 2) </td><td>float64</td><td>[[5.74215005e-28 4.47063961e-17]]                  </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[5]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[1.47663355e-18]                                   </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1e-06                                              </td></tr>
# </tbody>
# </table>
# Optimization restart 7/10,  f =  25.367651522023657
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[1].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>163.69912                              </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[1].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.56957834 1.04601   ]                </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[7].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>7.736815584360358e-296                 </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[7].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.78066024 0.11446304]                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.8298819126696503                     </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[1].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[6.04074000e+00 3.00408066e-38]        </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.8881890431292137                     </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[1.09873    0.09531774]                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.9095161335031636                     </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.47565051 0.07281978]                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.1974027217431253                     </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[4].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.7884288921007349                     </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.9215717388896106                     </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.38527707 1.03814   ]                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.09932482912354883                    </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.9070133695101202                     </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.49620805 0.91747129]                </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[7].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[1.12118    0.75338246]                </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[0]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8, 8) </td><td>float64</td><td>[[0.08846238, 0.0012199, 0.14093649... </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[1]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8,)   </td><td>float64</td><td>[0.00996538, 0.00998452, 0.00998465... </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[2]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4, 4) </td><td>float64</td><td>[[0.07982518, 0.15318736, 0.06595431...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[3]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4,)   </td><td>float64</td><td>[0.00999866, 0.00999882, 0.00999915... </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[4]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1, 2) </td><td>float64</td><td>[[0.00474358 0.05802779]]              </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[5]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[0.00999999]                           </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.004463449697770748                   </td></tr>
# </tbody>
# </table>
# Optimization restart 8/10,  f =  -8.156678365423634
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                                                 </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[1].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>185.80028                                             </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# ...
# <tr><td>GPR.kernel._primitive_kernels[6].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[  15.60088 2805.17161]                               </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[7].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.48966285 0.25594696]                               </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[0]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8, 8) </td><td>float64</td><td>[[1.78769577e-173, 0.00000000e+000, 1.37276458e-024...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[1]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8,)   </td><td>float64</td><td>[21.01624, 21.58935, 54.58421...                      </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[2]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4, 4) </td><td>float64</td><td>[[3.35083198e-298, 4.33193707e-007, 1.95491390e+002...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[3]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4,)   </td><td>float64</td><td>[73.62514, 78.86472, 54.14534...                      </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[4]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1, 2) </td><td>float64</td><td>[[2.89340470e-26 2.33358805e-54]]                     </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[5]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[4.51180002e-90]                                      </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1e-06                                                 </td></tr>
# </tbody>
# </table>
# Optimization restart 9/10,  f =  -5.142792533580863
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                                              </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[1].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>187.99354                                          </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[1].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[8.44393926e-02 5.15102290e+02]                    </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[7].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>7.736815584360358e-296                             </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[7].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.53561397 0.93215655]                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.05489                                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[1].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[52.3029      0.11249716]                          </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>6.101577686145835e-95                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[  2.40717 263.00289]                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>5.823832487978423e-63                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[ 78.9377  232.00854]                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>4.797071134499797e-05                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[4].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>26.0092                                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>4.879262060140292e-74                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[  5.26811 218.10677]                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>2.5547236951849075e-39                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.8996840135903421e-31                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[  6.502   220.86146]                              </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[7].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.3669883  0.62546976]                            </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[0]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8, 8) </td><td>float64</td><td>[[2.92064967e-01, 7.24544500e+01, 4.36435931e-16...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[1]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8,)   </td><td>float64</td><td>[0.0297841, 0.02193866, 0.02927179...              </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[2]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4, 4) </td><td>float64</td><td>[[4.50472536e-01, 1.07641568e-02, 3.33415559e-45...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[3]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4,)   </td><td>float64</td><td>[0.18851718, 0.10530239, 0.11611117...             </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[4]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1, 2) </td><td>float64</td><td>[[5.43813824e-21 9.33401797e-47]]                  </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[5]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[166.00181]                                        </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1e-06                                              </td></tr>
# </tbody>
# </table>
# Optimization restart 10/10,  f =  -16.207611341287695
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                                                 </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[1].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>118.35037                                             </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[1][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[1].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[4910.06523 2921.18737]                               </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].variance
# GPR.kernel._primitive_kernels[7].base_kernel.variance                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>7.736815584360358e-296                                </td></tr>
# <tr><td>GPR.kernel.primitive_kernels[7][&#x27;params&#x27;][&#x27;base_kernel&#x27;].lengthscales
# GPR.kernel._primitive_kernels[7].base_kernel.lengthscales                                              </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.79268527 1.08014   ]                               </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1061.04477                                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[1].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[  78.52647 1005.69454]                               </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.0                                                   </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[2].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[1.67908693e-130 3.66034306e+003]                     </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1745.05806                                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[2170.28078 2511.56055]                               </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[3].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1414.15989                                            </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[4].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>849.54449                                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>892.44282                                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[1.06348000e+00 3.02899584e+03]                       </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[5].alpha       </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>266.05099                                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>896.28935                                             </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[6].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[2850.03356 3139.58913]                               </td></tr>
# <tr><td>GPR.kernel._primitive_kernels[7].period      </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.37610144 1.0326    ]                               </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[0]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8, 8) </td><td>float64</td><td>[[1.91783500e+002, 0.00000000e+000, 3.99956399e-239...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[1]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(8,)   </td><td>float64</td><td>[11.25467, 19.56151, 24.09888...                      </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[2]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4, 4) </td><td>float64</td><td>[[1.77459320e-217, 2.29123627e-075, 7.37451191e-094...</td></tr>
# <tr><td>GPR.kernel._nkn_parameters[3]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(4,)   </td><td>float64</td><td>[25.22088, 36.48696, 55.78866...                      </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[4]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1, 2) </td><td>float64</td><td>[[0.00000000e+00 3.44148557e-31]]                     </td></tr>
# <tr><td>GPR.kernel._nkn_parameters[5]                </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[0.00060121]                                          </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1e-06                                                 </td></tr>
# </tbody>
# </table>

# %%
vmax = high(xm).max()
vmin = high(xm).min()
fig = plt.figure(figsize=(10,3))
ax = fig.add_subplot(131)
quad = ax.pcolormesh(x0m,x1m,high(xm),vmax=vmax,vmin=vmin)
ax.set_title("Exact")
ax.set_xlabel(r"$x_0$")
ax.set_ylabel(r"$x_1$")
fig.colorbar(quad)
ax = fig.add_subplot(132)
quad = ax.pcolormesh(x0m,x1m,mean_singlegp.reshape(x0m.shape),vmax=vmax,vmin=vmin)
ax.set_title("Single GP")
ax.set_xlabel(r"$x_0$")
ax.set_ylabel(r"$x_1$")
fig.colorbar(quad)
ax = fig.add_subplot(133)
quad = ax.pcolormesh(x0m,x1m,mean.reshape(x0m.shape),vmax=vmax,vmin=vmin)
ax.set_title("NARGP")
ax.set_xlabel(r"$x_0$")
ax.set_ylabel(r"$x_1$")
fig.colorbar(quad)
fig.tight_layout()
plt.show()

# %%
error_singlegp = mean_singlegp.reshape(x0m.shape)-high(xm)
error_nargp = mean.reshape(x0m.shape)-high(xm)
emax = max([error_singlegp.max(),-error_singlegp.min(),error_nargp.max(),-error_nargp.min()])
print(error_singlegp.max(),-error_singlegp.min(),error_nargp.max(),-error_nargp.min(),emax)

fig = plt.figure(figsize=(7,3))
ax = fig.add_subplot(121)
quad = ax.pcolormesh(x0m,x1m,error_singlegp,vmax=emax,vmin=-emax,cmap="bwr")
ax.set_title("Error (Single GP - Exact)")
ax.set_xlabel(r"$x_0$")
ax.set_ylabel(r"$x_1$")
fig.colorbar(quad)
ax = fig.add_subplot(122)
quad = ax.pcolormesh(x0m,x1m,error_nargp,vmax=emax,vmin=-emax,cmap="bwr")
ax.set_title("Error (NARGP - Exact)")
ax.set_xlabel(r"$x_0$")
ax.set_ylabel(r"$x_1$")
fig.colorbar(quad)
fig.tight_layout()
plt.show()
# Out:
# 2.4278400868062455 1.4322709093806907 10.63709280940563 1.2157039758646135 10.63709280940563

# %%
nsample = 1000
w0 = -5 + 15*np.random.rand(nsample)
w1 = 15 * np.random.rand(nsample)
xsample = np.stack([w0,w1],axis=-1)

t1=timer()
mean0, var0 = model_nargp.predict(xsample,ifidelity=0,nMonteCarlo=100)
t2=timer(); print(t2-t1, xsample.size); t1 = timer()
mean1, var1 = model_nargp.predict(xsample,ifidelity=1,nMonteCarlo=100)
t2=timer(); print(t2-t1, xsample.size); t1 = timer()
mean2, var2 = model_nargp.predict(xsample,ifidelity=2,nMonteCarlo=100)
t2=timer(); print(t2-t1, xsample.size); t1 = timer()
# Out:
# 0.4626576900482178 2000
# 2.5880086421966553 2000
# 89.36886930465698 2000

# %%
fig = plt.figure(figsize=(10,3))
ax = fig.add_subplot(131)
ax.plot(low(xsample),medium(xsample),".",markersize=1,label="Exact correlation")
ax.plot(mean0,mean1,".",markersize=1,label="NARGP")
ax.set_xlabel("Low-fidelity function")
ax.set_ylabel("Medium-fidelity function")
ax.legend()
ax = fig.add_subplot(132)
ax.plot(low(xsample),high(xsample),".",markersize=1,label="Exact correlation")
ax.plot(mean0,mean2,".",markersize=1,label="NARGP")
ax.set_xlabel("Low-fidelity function")
ax.set_ylabel("High-fidelity function")
ax.legend()
ax = fig.add_subplot(133)
ax.plot(medium(xsample),high(xsample),".",markersize=1,label="Exact correlation")
ax.plot(mean1,mean2,".",markersize=1,label="NARGP")
ax.set_xlabel("Medium-fidelity function")
ax.set_ylabel("High-fidelity function")
fig.tight_layout()
ax.legend()
plt.show()

# %%
mean_singlegp, var_singlegp = model_singlegp.predict(xsample)
exact_high = high(xsample)[:,None]
print(exact_high.shape,mean_singlegp.shape)
R2_singlegp = float(1.0 - sum((exact_high-mean_singlegp)**2)/sum((exact_high-exact_high.mean())**2))
R2_nargp = float(1.0 - sum((exact_high-mean2)**2)/sum((exact_high-exact_high.mean())**2))

fig = plt.figure(figsize=(4,4))
ax = fig.add_subplot()
vmin = -10
vmax = 260
ax.plot(np.linspace(vmin,vmax,2),np.linspace(vmin,vmax,2),c="k",lw=0.5)
ax.plot(mean_singlegp,exact_high,".",c="tab:green",label="Single GP ($R^2=${:.5f})".format(R2_singlegp))
ax.plot(mean2,exact_high,".",c="b",label="NARGP ($R^2=${:.5f})".format(R2_nargp))
ax.set_xlabel("Posterior mean")
ax.set_ylabel("Exact solution")
ax.set_xlim(vmin,vmax)
ax.set_ylim(vmin,vmax)
ax.legend()
plt.show()
# Out:
# (1000, 1) (1000, 1)
# /tmp/ipykernel_5381/4000118320.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   R2_singlegp = float(1.0 - sum((exact_high-mean_singlegp)**2)/sum((exact_high-exact_high.mean())**2))
# /tmp/ipykernel_5381/4000118320.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   R2_nargp = float(1.0 - sum((exact_high-mean2)**2)/sum((exact_high-exact_high.mean())**2))
