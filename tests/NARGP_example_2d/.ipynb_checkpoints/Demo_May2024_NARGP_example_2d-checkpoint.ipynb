# %%
import sys
sys.path.append("../../")
from mfmodeling import NARGP, SingleGP

# Uncomment below to use GPy implementation.
# Note that only RBF kernel is supported in the GPy implementation now.
"""
from mfmodeling.SingleGP_GPy import SingleGP
from mfmodeling import set_gpy_usage_in_nargp
set_gpy_usage_in_nargp(True)
"""

help(NARGP)
# Out:
# 2024-09-03 05:14:17.851134: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-03 05:14:17.984604: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-03 05:14:18.023585: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-03 05:14:18.676462: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-09-03 05:14:18.676535: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-09-03 05:14:18.676543: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Help on class NARGP in module mfmodeling.NARGP:
#
# class NARGP(builtins.object)
#  |  NARGP(*args, **kwargs)
#  |
#  |  Nonlinear autoregressive multi-fidelity Gaussian process regression (NARGP).
#  |  P. Perdikaris, et al., "Nonlinear information fusion algorithms for data-efficient multi-fidelity modeling"
#  |  Proc. R. Soc. A 473, 20160751 (2017). http://dx.doi.org/10.1098/rspa.2016.0751
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, *args, **kwargs)
#  |      Parameters
#  |      ----------
#  |      data_list : list[nfidelity]
#  |          List of multi-fidelity training data of y=f(x), where input x and output y are vectors.
#  |
#  |          Structure of the list of data is as follow.
#  |          data_list[ 0] = [data_input_lowest[nsample_lowest,ninput],   data_output_lowest[nsample_lowest,noutput_lowest]]
#  |          data_list[ 1] = [data_input_1st[nsample_1st,ninput],         data_output_1st[nsample_1st,noutput_1st]]
#  |          ...
#  |          data_list[-1] = [data_input_highest[nsample_highest,ninput], data_output_highest[nsample_highest,noutput_highest]]
#  |
#  |          "ninput" (dimension of the input vector x) is the same for all fidelities, while "noutput_***" (dimension of
#  |          the output vector y) and "nsample_***" (number of sampling of data set) can be different for each fidelity.
#  |      single_gp_config_list : list[dict]
#  |          List of dictionaries containing the arguments for each SingleGP class constructor.
#  |          single_gp_config_list[i] contains the arguments for i-th fidelity data.
#  |      normalize : Bool
#  |          Options for normalizing input data list.
#  |
#  |  optimize(self, **kwargs)
#  |      Optimization of the hyperparameters in NARGP.
#  |
#  |      Parameters
#  |      ----------
#  |      optimize_restarts : Int
#  |          Number of iterations in the optimize_restart method.
#  |      max_iters : Int
#  |          Maximum number of iterations in the optimization algorithm.
#  |      optimizer_name : Str
#  |          TensorFlow optimizer name. Either "Scipy" and "Adam", which use
#  |          gpflow.optimizer.Scipy and tf.optimizer.Adam, respectively,
#  |          are available. Default to "Scipy".
#  |      optimizer_parameters: Dict
#  |          Optional detailed optimization settings.
#  |      nMonteCarlo : Int
#  |          Number of Monte Carlo sampling points for prediction called in NARGP.
#  |      verbose : Bool
#  |          Shows progress of the __optimize_restart if True.
#  |      plot_history : Bool
#  |          Shows history of the objective function in the __optimize_restart if True.
#  |      optimize_noise_in_first_step : Bool
#  |          Optimize noise level in the first step if True.
#  |      use_built_in_initialization : Bool
#  |          Use hyper parameter initialization method (if any) of the kernel.
#  |
#  |  predict(self, x, ifidelity=None, nMonteCarlo=1000, called_in_optimize=False)
#  |      Parameters
#  |      ----------
#  |      x : Numpy.ndarray[..., ninput]
#  |          The points at which to make a prediction
#  |      ifidelity : Int
#  |          0 < ifidelity < nfidelity-1
#  |          Prediction for the specified fidelity model
#  |      nMonteCarlo : Int
#  |          Sampling number of Monte Carlo integration of Eq. (2.14)
#  |      called_in_optimize : Bool
#  |
#  |
#  |      Returns
#  |      -------
#  |      mean : Numpy.ndarray[..., noutput]
#  |          Mean for i-fidelity model
#  |      variance : Numpy.ndarray[..., noutput]
#  |          Variance for i-th fidelity model
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  data_list
#  |
#  |  kernel_list
#  |
#  |  model_list
#  |
#  |  single_gp_list
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# ### Preparation of data set

# %%
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt

np.random.seed(11)
tf.random.set_seed(11)

def high(x):
    '''
    Exact Branin function f_3
    '''
    x1 = x[...,0]
    x2 = x[...,1]
    return (-1.275*x1**2 / np.pi**2 + 5.0*x1/np.pi + x2 - 6.0)**2 + (10.0 - 5.0/(4.0*np.pi))*np.cos(x1) + 10.0

def medium(x):
    '''
    Medium-fidelity function f_2
    P. Perdikaris, et al., "Nonlinear information fusion algorithms for data-efficient multi-fidelity modeling"
    Proc. R. Soc. A 473, 20160751 (2017). http://dx.doi.org/10.1098/rspa.2016.0751
    '''
    x1 = x[...,0]
    x2 = x[...,1]
    return 10.0*np.sqrt(high(x-2.0)) + 2.0*(x1-0.5)-3.0*(3.0*x2-1.0) - 1.0

def low(x):
    '''
    Low-fidelity function f_2
    P. Perdikaris, et al., "Nonlinear information fusion algorithms for data-efficient multi-fidelity modeling"
    Proc. R. Soc. A 473, 20160751 (2017). http://dx.doi.org/10.1098/rspa.2016.0751
    '''
    x1 = x[...,0]
    x2 = x[...,1]
    return medium(1.2*(x+2.0)) - 3.0*x2 + 1.0

def scale_range(x,ub,lb):
    Np = x.shape[0]
    dim = x.shape[1]
    for i in range(0,Np):
        for j in range(0,dim):
            tmp = ub[j] -lb[j]
            x[i][j] = tmp*x[i][j] + lb[j]
    return x

def rmse(pred, truth):
    pred = pred.flatten()
    truth = truth.flatten()
    return np.sqrt(np.mean((pred-truth)**2))


nlow = 80
w0 = -5 + 15*np.random.rand(nlow)
w1 = 15 * np.random.rand(nlow)
data_low_x = np.stack([w0,w1],axis=-1)
data_low_y = low(data_low_x)

nmed = 40
perm = np.random.permutation(nlow)
data_med_x = data_low_x[perm[0:nmed],:]

# data_restrict = data_med_x[data_med_x[:,0]<5]
data_restrict = data_med_x[data_med_x[:,1]<10]
nhigh = 20
if data_restrict.shape[0] < nhigh:
    print("Data points in the restricted region is too small")
else:
    perm = np.random.permutation(data_restrict.shape[0])
    data_high_x = data_restrict[perm[0:nhigh],:]

# %%
fig = plt.figure(figsize=(4,4))
ax = fig.add_subplot()
ax.plot(data_low_x[:,0],data_low_x[:,1],"+",label=r"Low-fidelity $x$")
ax.plot(data_med_x[:,0],data_med_x[:,1],"x",label=r"Medium-fidelity $x$")
ax.plot(data_high_x[:,0],data_high_x[:,1],".",label=r"High-fidelity $x$")
ax.set_xlabel(r"$x_1$")
ax.set_ylabel(r"$x_2$")
ax.set_xlim(-5,10)
ax.set_ylim(0,15)
ax.legend(loc="lower left", bbox_to_anchor=(1,0))
plt.show()

# %%
# 推定に用いる入力データ: Low, medium, high-fidelity dataset
data_low_y = low(data_low_x)
data_med_y = medium(data_med_x)
data_high_y = high(data_high_x)

# データセットの描画
# %matplotlib inline
# %matplotlib qt
x0 = np.linspace(-5,10,20)
x1 = np.linspace(0,15,20)
x0m, x1m = np.meshgrid(x0,x1)
xm = np.stack([x0m,x1m],axis=-1)

fig = plt.figure()
ax = fig.add_subplot(projection="3d")
ax.plot_wireframe(x0m,x1m,high(xm),lw=0.5,color="black",label="High-fidelity function")
ax.plot(data_high_x[:,0],data_high_x[:,1],data_high_y,"*",label="Input data for GP")
ax.set_xlabel(r"x_0")
ax.set_ylabel(r"x_1")
ax.set_zlim(-100,300)
ax.view_init(30,-150)
ax.legend()
plt.show()

fig = plt.figure()
ax = fig.add_subplot(projection="3d")
ax.plot_wireframe(x0m,x1m,medium(xm),lw=0.5,color="black",label="Medium-fidelity function")
ax.plot(data_med_x[:,0],data_med_x[:,1],data_med_y,"*",label="Input data for GP")
ax.set_xlabel(r"x_0")
ax.set_ylabel(r"x_1")
ax.set_zlim(-100,300)
ax.view_init(30,-150)
ax.legend()
plt.show()

fig = plt.figure()
ax = fig.add_subplot(projection="3d")
ax.plot_wireframe(x0m,x1m,low(xm),lw=0.5,color="black",label="Low-fidelity function")
ax.plot(data_low_x[:,0],data_low_x[:,1],data_low_y,"*",label="Input data for GP")
ax.set_xlabel(r"x_0")
ax.set_ylabel(r"x_1")
ax.set_zlim(-100,300)
ax.view_init(30,-150)
ax.legend()
plt.show()

# %% [markdown]
# ### Nonlinear autoregressive multi-fidelity Gaussian process regression (NARGP)

# %%
# Set kernel name to use
KERNEL_NAME = "RBF"
#KERNEL_NAME = "SpectralMixture"
#KERNEL_NAME = "NeuralKernelNetwork"

data_list = [[data_low_x,data_low_y[:,None]],
             [data_med_x,data_med_y[:,None]],
             [data_high_x,data_high_y[:,None]]]
single_gp_config_list = [
    {"kernel": KERNEL_NAME},
    {"kernel": KERNEL_NAME},
    {"kernel": KERNEL_NAME},
]

# Uncomment the following to use different kernel for different fidelity data.
# However, if GPy implementation are being used,
# Spectral Mixture Kernel and Neural Kernel Network are not implemented,
# so RBF will be used.

# Different kernel for each fidelity
#single_gp_config_list = [
#    {"kernel": "RBF"},
#    {"kernel": "SpectralMixture"},
#    {"kernel": "NeuralKernelNetwork"},
#]

# Different initialization for each fidelity
#single_gp_config_list = [
#    {"kernel": "RBF", "kernel_args": {"lengthscales": [1.0, 1.0]}},
#    {"kernel": "RBF", "kernel_args": {"lengthscales": [2.0, 2.0]}},
#    {"kernel": "RBF", "kernel_args": {"lengthscales": [3.0, 3.0]}},
#]

model_nargp = NARGP(
    data_list = data_list,
    single_gp_config_list=single_gp_config_list,
    normalize=True)
from time import time as timer
t1=timer()
model_nargp.optimize(optimize_restarts=10, nMonteCarlo=1000, verbose=True)
t2=timer(); print(t2-t1, xm.size)

t1=timer()
mean, var = model_nargp.predict(xm.reshape(xm.size//2,2),nMonteCarlo=100)
t2=timer(); print(t2-t1, xm.size)
# Out:
# NARGP is using GPflow.
# nfidelity= 3 , optimize_restarts= 10 , max_iters= 400
# optimize_restarts= 10 , max_iters= 400
# 2024-09-03 05:14:23.109251: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-09-03 05:14:23.152868: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-09-03 05:14:23.156552: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-09-03 05:14:23.160555: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-03 05:14:23.161014: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-09-03 05:14:23.164624: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-09-03 05:14:23.167975: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-09-03 05:14:23.987486: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-09-03 05:14:23.990051: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-09-03 05:14:23.992028: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-09-03 05:14:23.993912: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13600 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:1e.0, compute capability: 7.5
# 2024-09-03 05:14:27.013801: I tensorflow/core/util/cuda_solvers.cc:179] Creating GpuSolver handles for stream 0x87df660
# Optimization restart 1/10,  f =  -78.79129224576441
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.31033                </td></tr>
# <tr><td>GPR.kernel.lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.37594875 2.20992   ]</td></tr>
# <tr><td>GPR.likelihood.variance</td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>8.071188668788969e-05  </td></tr>
# </tbody>
# </table>
# Optimization restart 2/10,  f =  -78.79129224981216
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.3104                 </td></tr>
# <tr><td>GPR.kernel.lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.37595064 2.20992   ]</td></tr>
# <tr><td>GPR.likelihood.variance</td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>8.071427483864186e-05  </td></tr>
# </tbody>
# </table>
# Optimization restart 3/10,  f =  -78.79129224938225
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.31037                </td></tr>
# <tr><td>GPR.kernel.lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.37595092 2.20992   ]</td></tr>
# <tr><td>GPR.likelihood.variance</td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>8.071400369448108e-05  </td></tr>
# </tbody>
# </table>
# Optimization restart 4/10,  f =  -78.79129224979988
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.31039                </td></tr>
# <tr><td>GPR.kernel.lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.37595046 2.20992   ]</td></tr>
# <tr><td>GPR.likelihood.variance</td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>8.071351231421964e-05  </td></tr>
# </tbody>
# </table>
# Optimization restart 5/10,  f =  -78.79129224936207
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.31038                </td></tr>
# <tr><td>GPR.kernel.lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.37595083 2.20992   ]</td></tr>
# <tr><td>GPR.likelihood.variance</td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>8.07139997433397e-05   </td></tr>
# </tbody>
# </table>
# Optimization restart 6/10,  f =  -78.7912922501588
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.31039                </td></tr>
# <tr><td>GPR.kernel.lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.37595055 2.20992   ]</td></tr>
# <tr><td>GPR.likelihood.variance</td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>8.071380424570677e-05  </td></tr>
# </tbody>
# </table>
# Optimization restart 7/10,  f =  -78.79129225016251
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.31039                </td></tr>
# <tr><td>GPR.kernel.lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.37595047 2.20992   ]</td></tr>
# <tr><td>GPR.likelihood.variance</td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>8.071374338141731e-05  </td></tr>
# </tbody>
# </table>
# Optimization restart 8/10,  f =  -78.79129224915077
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.31037                </td></tr>
# <tr><td>GPR.kernel.lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.37595005 2.20992   ]</td></tr>
# <tr><td>GPR.likelihood.variance</td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>8.071345110442099e-05  </td></tr>
# </tbody>
# </table>
# Optimization restart 9/10,  f =  -78.79129224979121
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.31039                </td></tr>
# <tr><td>GPR.kernel.lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.37595062 2.20992   ]</td></tr>
# <tr><td>GPR.likelihood.variance</td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>8.071410544374812e-05  </td></tr>
# </tbody>
# </table>
# Optimization restart 10/10,  f =  -78.79129222888731
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.31019                </td></tr>
# <tr><td>GPR.kernel.lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.37594996 2.20991   ]</td></tr>
# <tr><td>GPR.likelihood.variance</td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>8.071293964111722e-05  </td></tr>
# </tbody>
# </table>
# optimize_restarts= 10 , max_iters= 400
# Optimization restart 1/10,  f =  -37.007937438062285
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.kernels[0].kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>19.55761               </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.32221512 1.39965   ]</td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.0026337238052207973  </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[1492.02078]           </td></tr>
# <tr><td>GPR.kernel.kernels[1].variance               </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>7.1778                 </td></tr>
# <tr><td>GPR.kernel.kernels[1].lengthscales           </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[1.75466 3.4847 ]      </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1e-06                  </td></tr>
# </tbody>
# </table>
# Optimization restart 2/10,  f =  -37.00788869580363
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.kernels[0].kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.009038613970847334   </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.32220845 1.39967   ]</td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>5.69871                </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[686.67998]            </td></tr>
# <tr><td>GPR.kernel.kernels[1].variance               </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>7.18572                </td></tr>
# <tr><td>GPR.kernel.kernels[1].lengthscales           </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[1.75506 3.48535]      </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1e-06                  </td></tr>
# </tbody>
# </table>
# Optimization restart 3/10,  f =  -37.15771839996694
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.kernels[0].kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.017224284383223012   </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.32975472 1.47787   ]</td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.44721                </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[1011.6176]            </td></tr>
# <tr><td>GPR.kernel.kernels[1].variance               </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>7.93092                </td></tr>
# <tr><td>GPR.kernel.kernels[1].lengthscales           </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[1.79716 3.63543]      </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>2.821375669604986e-06  </td></tr>
# </tbody>
# </table>
# Optimization restart 4/10,  f =  -37.007917786667626
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.kernels[0].kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>6.09345                </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.32221351 1.39965   ]</td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.008452797181455179   </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[942.81671]            </td></tr>
# <tr><td>GPR.kernel.kernels[1].variance               </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>7.18386                </td></tr>
# <tr><td>GPR.kernel.kernels[1].lengthscales           </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[1.75499 3.48503]      </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1e-06                  </td></tr>
# </tbody>
# </table>
# Optimization restart 5/10,  f =  -37.00792651448616
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.kernels[0].kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.017647695970855547   </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.32221241 1.39968   ]</td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>2.91881                </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[1096.40007]           </td></tr>
# <tr><td>GPR.kernel.kernels[1].variance               </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>7.18023                </td></tr>
# <tr><td>GPR.kernel.kernels[1].lengthscales           </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[1.75486 3.48476]      </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1e-06                  </td></tr>
# </tbody>
# </table>
# Optimization restart 6/10,  f =  -37.00792388936746
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.kernels[0].kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.01898317652874583    </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.32224043 1.39963   ]</td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>2.71485                </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[1053.28417]           </td></tr>
# <tr><td>GPR.kernel.kernels[1].variance               </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>7.18158                </td></tr>
# <tr><td>GPR.kernel.kernels[1].lengthscales           </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[1.75492 3.48491]      </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1e-06                  </td></tr>
# </tbody>
# </table>
# Optimization restart 7/10,  f =  -37.00792415234484
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.kernels[0].kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.003016907837356262   </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.32221028 1.39958   ]</td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>17.07247               </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[1060.19749]           </td></tr>
# <tr><td>GPR.kernel.kernels[1].variance               </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>7.17421                </td></tr>
# <tr><td>GPR.kernel.kernels[1].lengthscales           </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[1.75461 3.48406]      </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1e-06                  </td></tr>
# </tbody>
# </table>
# Optimization restart 8/10,  f =  -37.00791126183397
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.kernels[0].kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.84021                </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.32220409 1.39967   ]</td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.02798574200564897    </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[864.88461]            </td></tr>
# <tr><td>GPR.kernel.kernels[1].variance               </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>7.18359                </td></tr>
# <tr><td>GPR.kernel.kernels[1].lengthscales           </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[1.75495 3.48545]      </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1e-06                  </td></tr>
# </tbody>
# </table>
# Optimization restart 9/10,  f =  -21.316774541100685
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.kernels[0].kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.63436                </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.51084636 2.11725   ]</td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.29998                </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[12.64872]             </td></tr>
# <tr><td>GPR.kernel.kernels[1].variance               </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.0711920346591895e-06 </td></tr>
# <tr><td>GPR.kernel.kernels[1].lengthscales           </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.18550081 0.0043945 ]</td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>7.364097658451734e-06  </td></tr>
# </tbody>
# </table>
# Optimization restart 10/10,  f =  -37.15771093490203
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.kernels[0].kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.005148333091934359   </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.32975088 1.47782   ]</td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>11.53126               </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[903.92407]            </td></tr>
# <tr><td>GPR.kernel.kernels[1].variance               </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>7.92954                </td></tr>
# <tr><td>GPR.kernel.kernels[1].lengthscales           </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[1.79711 3.63532]      </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>2.820940637920311e-06  </td></tr>
# </tbody>
# </table>
# optimize_restarts= 10 , max_iters= 400
# Optimization restart 1/10,  f =  -4.697099859838151
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.kernels[0].kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.8074191881679107e-06 </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.49865877 0.64600977]</td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.2032947729081373e-05 </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[1.33494]              </td></tr>
# <tr><td>GPR.kernel.kernels[1].variance               </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>12.18365               </td></tr>
# <tr><td>GPR.kernel.kernels[1].lengthscales           </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.8205608 3.69209  ]  </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.0001890975689098e-06 </td></tr>
# </tbody>
# </table>
# Optimization restart 2/10,  f =  3.0205333939624808
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                          </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.kernels[0].kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.53294                        </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[4.79082 1.83995]              </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.02739                        </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[0.54532706]                   </td></tr>
# <tr><td>GPR.kernel.kernels[1].variance               </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>9.866296368150256e-18          </td></tr>
# <tr><td>GPR.kernel.kernels[1].lengthscales           </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[3.68925053e-08 1.05914092e-05]</td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.0000022834316561e-06         </td></tr>
# </tbody>
# </table>
# Optimization restart 3/10,  f =  -13.03371726271725
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                          </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.kernels[0].kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.9010946431696127             </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[ 4.04713 13.40896]            </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>2947.16324                     </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[162621.39608]                 </td></tr>
# <tr><td>GPR.kernel.kernels[1].variance               </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.28194                        </td></tr>
# <tr><td>GPR.kernel.kernels[1].lengthscales           </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[7.71273384e-01 1.10202639e+05]</td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1e-06                          </td></tr>
# </tbody>
# </table>
# Optimization restart 4/10,  f =  -7.143423959601932
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.kernels[0].kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>87.2999                </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.92792823 8.12486   ]</td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.43053385088682017    </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[14933.43453]          </td></tr>
# <tr><td>GPR.kernel.kernels[1].variance               </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>14.54929               </td></tr>
# <tr><td>GPR.kernel.kernels[1].lengthscales           </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[148.94814   4.08875]  </td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1e-06                  </td></tr>
# </tbody>
# </table>
# Optimization restart 5/10,  f =  -4.697106778558336
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.kernels[0].kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>6.593252773379895e-10  </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.70576075 1.84291   ]</td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.1798341612979177e-09 </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[3.41145]              </td></tr>
# <tr><td>GPR.kernel.kernels[1].variance               </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>12.17429               </td></tr>
# <tr><td>GPR.kernel.kernels[1].lengthscales           </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.82049081 3.69098   ]</td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.0000000000016305e-06 </td></tr>
# </tbody>
# </table>
# Optimization restart 6/10,  f =  -13.033682885111165
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                          </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.kernels[0].kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>2.23285                        </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[ 4.04671 13.40536]            </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1188.41652                     </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[128119.71136]                 </td></tr>
# <tr><td>GPR.kernel.kernels[1].variance               </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.28086                        </td></tr>
# <tr><td>GPR.kernel.kernels[1].lengthscales           </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[7.71260707e-01 1.06505262e+05]</td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1e-06                          </td></tr>
# </tbody>
# </table>
# Optimization restart 7/10,  f =  -4.697106777360631
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.kernels[0].kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>2.379962621027515e-12  </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.04954233 6.57348   ]</td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>4.755441886083242e-14  </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[0.97869457]           </td></tr>
# <tr><td>GPR.kernel.kernels[1].variance               </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>12.17428               </td></tr>
# <tr><td>GPR.kernel.kernels[1].lengthscales           </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.82049074 3.69098   ]</td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.0000000304883256e-06 </td></tr>
# </tbody>
# </table>
# Optimization restart 8/10,  f =  -13.033716971788301
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                          </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.kernels[0].kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>4.18865                        </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[ 4.04701 13.40509]            </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>633.53108                      </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[171227.87099]                 </td></tr>
# <tr><td>GPR.kernel.kernels[1].variance               </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>3.28171                        </td></tr>
# <tr><td>GPR.kernel.kernels[1].lengthscales           </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[7.71278352e-01 2.00696942e+04]</td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1e-06                          </td></tr>
# </tbody>
# </table>
# Optimization restart 9/10,  f =  -4.697103880314138
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.kernels[0].kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>485.62993              </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.82049187 3.69104   ]</td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.02506863469894212    </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[17142.18594]          </td></tr>
# <tr><td>GPR.kernel.kernels[1].variance               </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.0                    </td></tr>
# <tr><td>GPR.kernel.kernels[1].lengthscales           </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[ 521.9883  2589.81138]</td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1e-06                  </td></tr>
# </tbody>
# </table>
# Optimization restart 10/10,  f =  -4.697103928774858
# <table>
# <thead>
# <tr><th>name                                         </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.kernels[0].kernels[0].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.6245642702786632     </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[0].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.82048911 3.69095   ]</td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>19.49117               </td></tr>
# <tr><td>GPR.kernel.kernels[0].kernels[1].lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(1,)   </td><td>float64</td><td>[17277.90554]          </td></tr>
# <tr><td>GPR.kernel.kernels[1].variance               </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>0.0                    </td></tr>
# <tr><td>GPR.kernel.kernels[1].lengthscales           </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[1417.46551 3060.95228]</td></tr>
# <tr><td>GPR.likelihood.variance                      </td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1e-06                  </td></tr>
# </tbody>
# </table>
# 35.58147358894348 800
# 12.85235595703125 800

# %% [markdown]
# ### Single GP using only high-fidelity data (for comparison)

# %%
data = [data_high_x,data_high_y[:,None]]
model_singlegp = SingleGP(data = data, kernel=KERNEL_NAME, normalize=True)
model_singlegp.optimize(optimize_restarts=10, verbose=True)
mean_singlegp, var_singlegp = model_singlegp.predict(xm.reshape(xm.size//2,2))
# Out:
# optimize_restarts= 10 , max_iters= 400
# Optimization restart 1/10,  f =  -4.697104902839026
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>12.17457               </td></tr>
# <tr><td>GPR.kernel.lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.79175537 5.42011   ]</td></tr>
# <tr><td>GPR.likelihood.variance</td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.0000556362621416e-06 </td></tr>
# </tbody>
# </table>
# Optimization restart 2/10,  f =  -4.697106667881897
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>12.17427               </td></tr>
# <tr><td>GPR.kernel.lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.79175297 5.42007   ]</td></tr>
# <tr><td>GPR.likelihood.variance</td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.0000032816049114e-06 </td></tr>
# </tbody>
# </table>
# Optimization restart 3/10,  f =  -4.6971052810901455
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>12.17468               </td></tr>
# <tr><td>GPR.kernel.lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.79175603 5.42012   ]</td></tr>
# <tr><td>GPR.likelihood.variance</td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.0000444019967462e-06 </td></tr>
# </tbody>
# </table>
# Optimization restart 4/10,  f =  -4.697106771925462
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>12.17429               </td></tr>
# <tr><td>GPR.kernel.lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.79175307 5.42007   ]</td></tr>
# <tr><td>GPR.likelihood.variance</td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.0000001955283355e-06 </td></tr>
# </tbody>
# </table>
# Optimization restart 5/10,  f =  -4.697106778212973
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>12.17426               </td></tr>
# <tr><td>GPR.kernel.lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.79175275 5.42007   ]</td></tr>
# <tr><td>GPR.likelihood.variance</td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.0000000134620216e-06 </td></tr>
# </tbody>
# </table>
# Optimization restart 6/10,  f =  -4.697099846850392
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>12.17544               </td></tr>
# <tr><td>GPR.kernel.lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.79176109 5.42022   ]</td></tr>
# <tr><td>GPR.likelihood.variance</td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.0002054636532375e-06 </td></tr>
# </tbody>
# </table>
# Optimization restart 7/10,  f =  -4.69710485370198
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>12.181                 </td></tr>
# <tr><td>GPR.kernel.lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.79182126 5.42071   ]</td></tr>
# <tr><td>GPR.likelihood.variance</td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.0000485318139173e-06 </td></tr>
# </tbody>
# </table>
# Optimization restart 8/10,  f =  -4.697106747049215
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>12.17484             </td></tr>
# <tr><td>GPR.kernel.lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.7917534 5.42017  ]</td></tr>
# <tr><td>GPR.likelihood.variance</td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.000000796318215e-06</td></tr>
# </tbody>
# </table>
# Optimization restart 9/10,  f =  -4.697106722934457
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>12.17387               </td></tr>
# <tr><td>GPR.kernel.lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.79174817 5.42003   ]</td></tr>
# <tr><td>GPR.likelihood.variance</td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.0000016126807264e-06 </td></tr>
# </tbody>
# </table>
# Optimization restart 10/10,  f =  -4.6971067763447785
# <table>
# <thead>
# <tr><th>name                   </th><th>class    </th><th>transform       </th><th>prior  </th><th>trainable  </th><th>shape  </th><th>dtype  </th><th>value                  </th></tr>
# </thead>
# <tbody>
# <tr><td>GPR.kernel.variance    </td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>12.17429               </td></tr>
# <tr><td>GPR.kernel.lengthscales</td><td>Parameter</td><td>Softplus        </td><td>       </td><td>True       </td><td>(2,)   </td><td>float64</td><td>[0.79175312 5.42007   ]</td></tr>
# <tr><td>GPR.likelihood.variance</td><td>Parameter</td><td>Softplus + Shift</td><td>       </td><td>True       </td><td>()     </td><td>float64</td><td>1.0000000634366257e-06 </td></tr>
# </tbody>
# </table>

# %%
vmax = high(xm).max()
vmin = high(xm).min()
fig = plt.figure(figsize=(10,3))
ax = fig.add_subplot(131)
quad = ax.pcolormesh(x0m,x1m,high(xm),vmax=vmax,vmin=vmin)
ax.set_title("Exact")
ax.set_xlabel(r"$x_0$")
ax.set_ylabel(r"$x_1$")
fig.colorbar(quad)
ax = fig.add_subplot(132)
quad = ax.pcolormesh(x0m,x1m,mean_singlegp.reshape(x0m.shape),vmax=vmax,vmin=vmin)
ax.set_title("Single GP")
ax.set_xlabel(r"$x_0$")
ax.set_ylabel(r"$x_1$")
fig.colorbar(quad)
ax = fig.add_subplot(133)
quad = ax.pcolormesh(x0m,x1m,mean.reshape(x0m.shape),vmax=vmax,vmin=vmin)
ax.set_title("NARGP")
ax.set_xlabel(r"$x_0$")
ax.set_ylabel(r"$x_1$")
fig.colorbar(quad)
fig.tight_layout()
plt.show()

# %%
error_singlegp = mean_singlegp.reshape(x0m.shape)-high(xm)
error_nargp = mean.reshape(x0m.shape)-high(xm)
emax = max([error_singlegp.max(),-error_singlegp.min(),error_nargp.max(),-error_nargp.min()])
print(error_singlegp.max(),-error_singlegp.min(),error_nargp.max(),-error_nargp.min(),emax)

fig = plt.figure(figsize=(7,3))
ax = fig.add_subplot(121)
quad = ax.pcolormesh(x0m,x1m,error_singlegp,vmax=emax,vmin=-emax,cmap="bwr")
ax.set_title("Error (Single GP - Exact)")
ax.set_xlabel(r"$x_0$")
ax.set_ylabel(r"$x_1$")
fig.colorbar(quad)
ax = fig.add_subplot(122)
quad = ax.pcolormesh(x0m,x1m,error_nargp,vmax=emax,vmin=-emax,cmap="bwr")
ax.set_title("Error (NARGP - Exact)")
ax.set_xlabel(r"$x_0$")
ax.set_ylabel(r"$x_1$")
fig.colorbar(quad)
fig.tight_layout()
plt.show()
# Out:
# 8.874343769563374 23.87261754724814 9.629539874415745 7.304718125425012 23.87261754724814

# %%
nsample = 1000
w0 = -5 + 15*np.random.rand(nsample)
w1 = 15 * np.random.rand(nsample)
xsample = np.stack([w0,w1],axis=-1)

t1=timer()
mean0, var0 = model_nargp.predict(xsample,ifidelity=0,nMonteCarlo=100)
t2=timer(); print(t2-t1, xsample.size); t1 = timer()
mean1, var1 = model_nargp.predict(xsample,ifidelity=1,nMonteCarlo=100)
t2=timer(); print(t2-t1, xsample.size); t1 = timer()
mean2, var2 = model_nargp.predict(xsample,ifidelity=2,nMonteCarlo=100)
t2=timer(); print(t2-t1, xsample.size); t1 = timer()
# Out:
# 0.030024290084838867 2000
# 0.14041399955749512 2000
# 15.751917362213135 2000

# %%
fig = plt.figure(figsize=(10,3))
ax = fig.add_subplot(131)
ax.plot(low(xsample),medium(xsample),".",markersize=1,label="Exact correlation")
ax.plot(mean0,mean1,".",markersize=1,label="NARGP")
ax.set_xlabel("Low-fidelity function")
ax.set_ylabel("Medium-fidelity function")
ax.legend()
ax = fig.add_subplot(132)
ax.plot(low(xsample),high(xsample),".",markersize=1,label="Exact correlation")
ax.plot(mean0,mean2,".",markersize=1,label="NARGP")
ax.set_xlabel("Low-fidelity function")
ax.set_ylabel("High-fidelity function")
ax.legend()
ax = fig.add_subplot(133)
ax.plot(medium(xsample),high(xsample),".",markersize=1,label="Exact correlation")
ax.plot(mean1,mean2,".",markersize=1,label="NARGP")
ax.set_xlabel("Medium-fidelity function")
ax.set_ylabel("High-fidelity function")
fig.tight_layout()
ax.legend()
plt.show()

# %%
mean_singlegp, var_singlegp = model_singlegp.predict(xsample)
exact_high = high(xsample)[:,None]
print(exact_high.shape,mean_singlegp.shape)
R2_singlegp = float(1.0 - sum((exact_high-mean_singlegp)**2)/sum((exact_high-exact_high.mean())**2))
R2_nargp = float(1.0 - sum((exact_high-mean2)**2)/sum((exact_high-exact_high.mean())**2))

fig = plt.figure(figsize=(4,4))
ax = fig.add_subplot()
vmin = -10
vmax = 260
ax.plot(np.linspace(vmin,vmax,2),np.linspace(vmin,vmax,2),c="k",lw=0.5)
ax.plot(mean_singlegp,exact_high,".",c="tab:green",label="Single GP ($R^2=${:.5f})".format(R2_singlegp))
ax.plot(mean2,exact_high,".",c="b",label="NARGP ($R^2=${:.5f})".format(R2_nargp))
ax.set_xlabel("Posterior mean")
ax.set_ylabel("Exact solution")
ax.set_xlim(vmin,vmax)
ax.set_ylim(vmin,vmax)
ax.legend()
plt.show()
# Out:
# (1000, 1) (1000, 1)
# /tmp/ipykernel_2070/4000118320.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   R2_singlegp = float(1.0 - sum((exact_high-mean_singlegp)**2)/sum((exact_high-exact_high.mean())**2))
# /tmp/ipykernel_2070/4000118320.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   R2_nargp = float(1.0 - sum((exact_high-mean2)**2)/sum((exact_high-exact_high.mean())**2))
