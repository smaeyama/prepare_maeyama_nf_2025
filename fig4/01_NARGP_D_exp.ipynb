# %%
import sys
sys.path.append("../")
from mfmodeling import NARGP, SingleGP
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import optimize
import pickle

# Set kernel name to use
# KERNEL_NAME = "RBF"
# KERNEL_NAME = "SpectralMixture"
KERNEL_NAME = "NeuralKernelNetwork"

# %% [markdown]
# ### Read dataset

# %%
df = pd.read_csv("./data/JET_data_Narita2023CPP_fig1.csv")
df = df[df["D_exp"]>0].copy()
print(df.columns)

D_exp_threshold = df["D_exp"].median()

df_train = df[df["D_exp"]>D_exp_threshold].copy()
df_test = df[df["D_exp"]<=D_exp_threshold].copy()
print(df.shape)
print(df_train.shape)
print(df_test.shape)
# Out:
# Index(['R/Ln', 'R/LTe', 'R/LTi', 'ni/ne', 'Te/Ti', 'beta', 'nu_ee', 'q', 's',
#        'epsilon', 'kappa', 'delta', 'C_T', 'C_P', 'C_N', 'C_HP',
#        'chi_e_eff/chi_i_eff', 'ktheta', 'gamma', 'D_exp', 'Q_e_exp'],
#       dtype='object')
# (135, 21)
# (67, 21)
# (68, 21)

# %%
fig = plt.figure(figsize=(12,6))
fig.suptitle("D_exp")
nl=3; nc=4; i=0
for l in range(nl):
    for c in range(nc):
        ax = fig.add_subplot(nl,nc,1+i)
        ax.plot(df.iloc[:,i],df["D_exp"],"x",label="All data")
        ax.plot(df_train.iloc[:,i],df_train["D_exp"],".",label="Train")
        ax.plot(df_test.iloc[:,i],df_test["D_exp"],".",label="Test")
        ax.set_xlabel(df_train.columns[i])
        # ax.set_xscale("log")
        ax.set_yscale("log")
        if i==0:
            ax.legend()
        i=i+1
fig.tight_layout()
plt.show()

# %%
def D_model_eq6(param,df):
    c0, alpha, beta = param
    Z_i = 1
    nu_ii = Z_i**4 * df["ni/ne"] * df["Te/Ti"]**2 * df["nu_ee"]
    nu_ii_star = nu_ii * df["q"] / df["epsilon"]**1.5
    tau_ii = 3*np.sqrt(np.pi)/(4*nu_ii)
    K_RH = 1/(1+1.6*df["q"]**2/np.sqrt(df["epsilon"]))
    tau_r_bar = np.sqrt(np.exp(-df["q"]**2)**2+K_RH**2*(tau_ii*df["epsilon"]/0.67)**2)
    mixing = np.array(df["gamma"]/df["ktheta"]**2)
    D_model = c0*mixing**alpha*(0.1*tau_r_bar*mixing**0.5)**beta
    return D_model

def fit_eq6(param,df,sol):
    # return np.abs(sol - D_model_eq6(param,df)) # Linear fit
    return np.abs(np.log(sol) - np.log(D_model_eq6(param,df))) # Log fit

param_eq6 = [1.55, 0.75, -1.2]
optimize_result = optimize.least_squares(fit_eq6, param_eq6, args=(df_train,df_train["D_exp"]))
param_eq6 = optimize_result.x
print(param_eq6)
# Out:
# [ 1.58562816  0.12906561 -0.11556239]

# %%
ans=np.array(df_test["D_exp"])
pred=D_model_eq6(param_eq6,df_test)
MSLE_eq6 = ((np.log(1+pred)-np.log(1+ans))**2).mean() # Linear fit
# R2_eq6 = 1 - np.sum((ans-pred)**2)/np.sum((ans-ans.mean())**2)
R2_eq6 = 1 - np.sum((np.log(ans)-np.log(pred))**2)/np.sum((np.log(ans)-np.log(ans).mean())**2)
print("MSLE=",MSLE_eq6, ", R^2=",R2_eq6)

fig=plt.figure()
ax = fig.add_subplot()
D_min = 0.02 #df_all["D_exp"].min()
D_max = 40 #df_all["D_exp"].max()
ax.plot([D_min,D_max],[D_min,D_max],"--",color="k",lw=1)
ax.plot(df_train["D_exp"],D_model_eq6(param_eq6,df_train),"g+",label="Train - Eq.(6)")
ax.plot(df_test["D_exp"],D_model_eq6(param_eq6,df_test),"r.",label="Test - Eq.(6)")
ax.set_xscale("log")
ax.set_yscale("log")
ax.set_xlim(D_min,D_max)
ax.set_ylim(D_min,D_max)
ax.set_aspect("equal")
ax.set_xlabel("D_exp")
ax.set_ylabel("D_model")
ax.legend()
plt.show()
# Out:
# MSLE= 0.35058577156921117 , R^2= -5.121357957182307

# %% [markdown]
# ### Single GP

# %%
# data_list = [[np.array(df_train)[:,:12],np.array(df_train["D_exp"])[:,np.newaxis]]] # Linear fit
data_list = [[np.array(df_train)[:,:12],np.log(np.array(df_train["D_exp"])[:,np.newaxis])]] # Log fit
print(data_list[0][0].shape, data_list[0][1].shape)
# model_singlegp = NARGP(data_list = data_list)             
# model_singlegp.optimize(optimize_restarts=20, max_iters=400)


single_gp_config_list = [
    {"kernel": KERNEL_NAME},
]
model_singlegp = NARGP(
    data_list = data_list,
    single_gp_config_list=single_gp_config_list,
    normalize=True)
model_singlegp.optimize()

if KERNEL_NAME == "RBF":
    with open("model_singleGP_RBF.pkl","wb") as f:
        pickle.dump(model_singlegp,f)
elif KERNEL_NAME == "SpectralMixture":
    with open("model_singleGP_SMK.pkl","wb") as f:
        pickle.dump(model_singlegp,f)
elif KERNEL_NAME == "NeuralKernelNetwork":
    with open("model_singleGP_NKN.pkl","wb") as f:
        pickle.dump(model_singlegp,f)


if KERNEL_NAME == "RBF":
    with open("model_singleGP_RBF.pkl","rb") as f:
        model_singlegp = pickle.load(f)
elif KERNEL_NAME == "SpectralMixture":
    with open("model_singleGP_SMK.pkl","rb") as f:
        model_singlegp = pickle.load(f)
elif KERNEL_NAME == "NeuralKernelNetwork":
    with open("model_singleGP_NKN.pkl","rb") as f:
        model_singlegp = pickle.load(f)
# Out:
# (67, 12) (67, 1)
# NARGP is using GPflow.
# 2025-09-25 13:15:22.383135: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:22.388298: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:22.393400: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:22.398025: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:22.403282: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:22.408826: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:22.414011: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:22.419129: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:22.424281: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:22.428868: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:22.433911: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:22.439100: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:22.444431: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:22.449987: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:22.454467: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:22.459865: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:22.465624: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:26.949158: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:26.955245: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:26.961048: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:26.965823: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:26.971822: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:26.977999: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:26.984240: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:26.990200: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:26.995810: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:27.002178: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:27.007923: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:27.014351: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:27.020290: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:27.026655: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:27.031372: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:27.037465: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:27.043732: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:27.049697: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:31.091164: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:31.096966: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:33.230675: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:33.237323: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:33.243722: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:33.250026: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:33.256461: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:33.269523: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:33.274358: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:33.280488: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:33.285135: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:33.291286: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:33.297197: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:33.303424: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:33.308432: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:33.313981: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:33.320089: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:33.326321: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:33.332947: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:33.369016: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:33.381557: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:35.322072: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:35.326651: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:35.332907: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:35.339040: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.157211: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.162568: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.168282: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.178933: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.184632: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.189992: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.195553: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.200851: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.206539: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.212019: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.216668: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.222140: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.227335: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.232642: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.238264: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.243772: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.248952: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.302050: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.307177: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.312861: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.318651: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.323964: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.329150: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.334810: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.340255: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.345749: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.351447: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.357393: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.362603: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.368199: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.374068: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.379724: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.385494: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.390895: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.396745: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.402591: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.408015: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.413545: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.419413: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.425102: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.430478: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.435149: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.440733: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.446786: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.452923: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.458949: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.464915: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.471022: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.476577: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.482463: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.488202: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.493925: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:39.499729: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:41.449145: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:41.454780: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:41.460103: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:41.464613: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:41.470381: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:41.487620: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:41.493750: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:41.499366: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:41.504984: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:41.511277: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:41.516705: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:41.522522: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:41.528637: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:41.534493: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:41.540712: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:41.546558: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:41.588600: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:43.544963: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:43.551090: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:43.563010: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:43.568708: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:43.574796: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:43.580478: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:43.586254: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:43.592414: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:43.597795: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:43.603678: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:43.609284: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:43.614733: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:43.619336: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:43.625307: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:43.630624: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:43.636671: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:43.642516: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:43.980507: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:45.996000: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:46.001384: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:46.006814: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:46.012529: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:46.018026: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:48.881310: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:50.949088: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:50.953894: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:50.959823: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:50.965888: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:50.971682: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:50.977202: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:50.981953: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:50.987818: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:50.993634: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:50.999601: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:51.005357: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:51.010694: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:51.016531: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:51.022668: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:51.029124: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:51.035344: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:51.041145: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:51.047283: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:51.979946: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:51.984975: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:51.990922: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:51.996836: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.002781: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.014005: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.018950: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.023661: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.028885: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.034700: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.040286: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.045930: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.051618: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.057429: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.063335: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.068625: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.073996: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.085595: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.091507: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.096867: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.102190: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.108086: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.113483: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.118093: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.122823: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.128255: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.133985: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.139784: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.145237: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.151099: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.156818: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.161816: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.167794: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.173841: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.180044: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.186518: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.192492: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.198766: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.205040: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.211372: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.217240: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.222708: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.228612: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.235039: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.241643: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.247864: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.254043: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.260519: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.266492: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:15:52.272823: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# ...
# 2025-09-25 13:16:34.715964: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:34.720364: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:34.725795: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:34.735421: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:34.740733: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:34.745896: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:34.750974: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:34.756213: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:34.761588: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:34.766686: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:34.771444: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:34.776633: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:34.781924: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:34.787142: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:34.792678: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:34.796891: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:35.287316: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:35.291633: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:35.297210: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:35.302215: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:35.307985: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:35.321625: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:35.325802: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:35.331378: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:35.337254: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:35.341506: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:35.345702: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:35.351314: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:35.357081: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:35.362788: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:35.368786: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:35.373344: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:35.481276: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:35.485650: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:37.898394: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:37.903990: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:37.909504: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:45.042545: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:45.048192: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:45.054242: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:45.060320: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:45.065965: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:45.071057: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:45.077195: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:45.082997: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:45.088787: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:45.094623: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:45.100457: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:45.106515: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:45.112228: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:45.117934: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:45.123397: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:45.129259: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:45.135155: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:45.141017: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:49.430857: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:49.436741: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:49.448344: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:49.453679: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:49.458602: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:49.463905: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:49.469279: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:49.474913: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:49.480332: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:49.484909: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:49.490274: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:49.494755: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:49.499240: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:49.503751: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:49.509111: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:49.514527: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:49.520358: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:49.700915: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:49.706507: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.

# %%
mean_train_1, var_train_1 = model_singlegp.predict(np.array(df_train)[:,:12])
mean_test_1, var_test_1 = model_singlegp.predict(np.array(df_test)[:,:12])

# ### Linear fit ###
# ans=np.array(df_test["D_exp"])
# pred=mean_test.ravel()
### Log fit ###
ans=np.array(df_test["D_exp"])
pred=np.exp(mean_test_1.ravel())

MSLE_singlegp = ((np.log(1+pred)-np.log(1+ans))**2).mean() # Linear fit
# R2 = 1 - np.sum((ans-pred)**2)/np.sum((ans-ans.mean())**2)
R2_singlegp = 1 - np.sum((np.log(ans)-np.log(pred))**2)/np.sum((np.log(ans)-np.log(ans).mean())**2)
print("MSLE=",MSLE_singlegp, ", R^2=",R2_singlegp)

fig=plt.figure()
ax = fig.add_subplot()
D_min = 0.02 #df_all["D_exp"].min()
D_max = 40 #df_all["D_exp"].max()
ax.plot([D_min,D_max],[D_min,D_max],"--",color="k",lw=1)
# ax.plot(df_train["D_exp"],mean_train,"o",label="Train") # Linear fit
# ax.plot(df_test["D_exp"],mean_test,"o",label="Test") # Linear fit
ax.plot(df_train["D_exp"],np.exp(mean_train_1),"g+",label="Train") # Log fit
ax.plot(df_test["D_exp"],np.exp(mean_test_1),"r.",label="Test") # Log fit
ax.set_xscale("log")
ax.set_yscale("log")
ax.set_xlim(D_min,D_max)
ax.set_ylim(D_min,D_max)
ax.set_aspect("equal")
ax.set_xlabel("D_exp")
ax.set_ylabel("D_model")
ax.legend()
plt.show()
# Out:
# MSLE= 0.10197675856093974 , R^2= -1.8294832868199307

# %% [markdown]
# ### Multi-fidelity regression by NARGP
# Low-fidelity data: (linearly most unstable wavenumber, growthrate)
# High-fidelity data: D_exp

# %%
# data_list = [[np.array(df)[:,:12],np.array(df)[:,17:19]],,
#              [np.array(df_train)[:,:12],np.array(df_train["D_exp"])[:,np.newaxis]]] # Linear fit
data_list = [[np.array(df)[:,:12],np.array(df)[:,17:19]],
             [np.array(df_train)[:,:12],np.log(np.array(df_train["D_exp"])[:,np.newaxis])]] # Log fit
print(data_list[0][0].shape, data_list[0][1].shape)
print(data_list[1][0].shape, data_list[1][1].shape)
# model_nargp = NARGP(data_list=data_list)             
# model_nargp.optimize(optimize_restarts=20, max_iters=400)

single_gp_config_list = [
    {"kernel": KERNEL_NAME},
    {"kernel": KERNEL_NAME},
]
model_nargp = NARGP(
    data_list = data_list,
    single_gp_config_list=single_gp_config_list,
    normalize=True)
model_nargp.optimize()


if KERNEL_NAME == "RBF":
    with open("model_NARGP_RBF.pkl","wb") as f:
        pickle.dump(model_nargp,f)
elif KERNEL_NAME == "SpectralMixture":
    with open("model_NARGP_SMK.pkl","wb") as f:
        pickle.dump(model_nargp,f)
elif KERNEL_NAME == "NeuralKernelNetwork":
    with open("model_NARGP_NKN.pkl","wb") as f:
        pickle.dump(model_nargp,f)


if KERNEL_NAME == "RBF":
    with open("model_NARGP_RBF.pkl","rb") as f:
        model_nargp = pickle.load(f)
elif KERNEL_NAME == "SpectralMixture":
    with open("model_NARGP_SMK.pkl","rb") as f:
        model_nargp = pickle.load(f)
elif KERNEL_NAME == "NeuralKernelNetwork":
    with open("model_NARGP_NKN.pkl","rb") as f:
        model_nargp = pickle.load(f)
# Out:
# (135, 12) (135, 2)
# (67, 12) (67, 1)
# NARGP is using GPflow.
# 2025-09-25 13:16:52.709762: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:52.716011: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:52.722141: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:52.728036: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:52.733812: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:52.739402: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:52.751065: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:52.757156: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:52.763188: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:52.769331: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:52.775450: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:52.780979: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:52.786665: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:52.792491: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:52.798424: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:52.804101: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:52.809884: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:52.939587: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:59.820842: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:59.827018: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:59.833562: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:59.839889: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:59.852121: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:59.858247: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:59.863941: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:59.870566: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:59.877037: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:59.883684: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:59.890234: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:59.896885: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:59.903482: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:59.910432: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:59.916764: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:59.923548: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:16:59.930127: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:04.725503: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:04.731620: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:04.737407: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:04.743196: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:06.826476: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:06.833091: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:09.138958: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:11.160565: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:11.166945: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:13.184416: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:13.190627: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:15.678103: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:15.684293: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:15.690340: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:15.696335: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:15.709088: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:15.721535: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:15.727881: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:15.733879: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:15.739929: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:15.745950: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:15.752156: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:15.758175: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:15.764116: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:15.770485: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:15.776878: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:15.782924: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:16.066482: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:18.260720: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:18.266317: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:18.272949: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:18.279578: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:18.286360: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:20.321127: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:20.327446: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:28.359377: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:28.365705: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:28.371885: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:28.378033: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:28.384473: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:28.391062: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:28.397376: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:28.403631: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:28.410015: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:28.416317: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:28.422575: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:28.428819: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:28.435153: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:28.441526: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:28.447684: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:28.454035: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:28.460579: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:28.466791: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:28.511411: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.539396: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.546042: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.552893: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.559498: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.565357: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.571633: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.578223: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.583815: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.590374: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.597127: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.602556: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.609054: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.614797: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.621210: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.627815: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.634386: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.641117: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.647650: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.654360: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.666302: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.671765: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.678009: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.684507: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.690955: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.697343: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.704007: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.710299: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.716901: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.723387: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.730038: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.736789: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.743843: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.750367: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.757118: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:30.763597: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:32.748836: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:32.755418: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:32.761821: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:32.768555: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:32.773975: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:32.780522: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:32.792886: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:32.799172: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:32.804814: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:32.810972: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:32.816970: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:32.823057: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:32.829010: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:32.835259: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:32.841742: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:32.847730: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:32.853631: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:32.859946: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:32.871721: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:32.878454: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:32.885120: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:34.952219: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:34.958646: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:34.965388: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:34.972417: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:37.190465: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:37.196717: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:37.202822: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:37.209710: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:37.223608: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:37.230132: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:37.236536: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:37.242448: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:37.248372: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:37.254112: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:37.259956: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:37.266670: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:37.273201: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:37.278894: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:37.285638: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:37.291899: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:37.297494: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:41.762086: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:41.768344: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:41.774602: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:43.733779: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:43.740243: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:43.751821: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:43.763683: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:43.768923: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:43.774373: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:43.779523: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:43.784584: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:43.789689: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:43.794792: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:43.799884: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:43.805438: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:43.810567: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:43.815713: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:43.822031: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:43.828323: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:48.269073: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:50.468229: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:50.473582: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:52.626399: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:52.631756: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:52.636821: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:52.648527: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:52.654620: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:52.660165: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:52.665336: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:52.670600: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:52.675795: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:52.680888: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:52.686175: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:52.691368: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:52.696454: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:52.701621: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:52.706716: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:52.711748: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:52.716818: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:53.179732: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:55.225448: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:55.231886: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:55.237157: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:55.242329: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:55.248303: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:55.253546: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:57.294720: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:59.406075: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:59.411219: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:59.416311: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:59.421356: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:59.426437: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:59.432784: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:59.438906: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:17:59.444078: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# ...
# 2025-09-25 13:22:54.027735: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:22:54.042729: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:22:54.053584: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:22:54.081008: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:22:54.093643: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:22:54.105486: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:22:54.120880: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:22:54.135909: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:22:54.150662: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:22:54.165523: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:22:54.180083: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:22:54.194823: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:22:54.209086: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:22:54.225321: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:22:54.237865: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:22:54.249824: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:22:54.260362: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:29.464895: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:29.477865: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:29.494299: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:29.510263: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:29.526131: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:29.541565: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:29.556567: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:29.571481: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:29.585918: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:29.600737: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:29.616768: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:29.632003: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:29.648581: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:29.664477: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:29.680346: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:29.695183: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:29.709743: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:29.721824: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:32.659723: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:32.675414: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:32.690956: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:32.706259: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:32.721720: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:32.737910: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:32.753529: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:32.768962: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:32.784733: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:32.800304: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:32.816022: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:32.831708: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:32.846537: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:32.856824: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:32.868538: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:32.880973: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:32.896816: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:32.912107: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:42.762693: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:42.779024: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:42.795051: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:50.558184: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:50.569047: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:50.581343: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:50.591571: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:50.607823: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:50.624325: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:50.640331: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:50.656132: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:50.671613: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:50.682182: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:50.698249: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:50.714117: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:50.730551: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:50.746249: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:50.762768: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:50.779398: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:50.795738: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.
# 2025-09-25 13:23:50.811796: W tensorflow/core/kernels/linalg/cholesky_op_gpu.cu.cc:206] Cholesky decomposition was not successful for batch 0. The input might not be valid. Filling lower-triangular output with NaNs.

# %%
mean_train, var_train = model_nargp.predict(np.array(df_train)[:,:12])
mean_test, var_test = model_nargp.predict(np.array(df_test)[:,:12])
# mean_train = mean_train + np.log(np.array(D_model_eq6(param_eq6,df_train))[:,np.newaxis])
# mean_test = mean_test + np.log(np.array(D_model_eq6(param_eq6,df_test))[:,np.newaxis])

# ### Linear fit ###
# ans=np.array(df_test["D_exp"])
# pred=mean_test.ravel().copy()
### Log fit ###
ans=np.array(df_test["D_exp"])
pred=np.exp(mean_test.ravel())

MSLE=((np.log(1+pred)-np.log(1+ans))**2).mean()
# R2 = 1 - np.sum((ans-pred)**2)/np.sum((ans-ans.mean())**2)
R2 = 1 - np.sum((np.log(ans)-np.log(pred))**2)/np.sum((np.log(ans)-np.log(ans).mean())**2)
print("MSLE=",MSLE, ", R^2=",R2)

fig=plt.figure()
ax = fig.add_subplot()
D_min = 0.02 #df_all["D_exp"].min()
D_max = 40 #df_all["D_exp"].max()
ax.plot([D_min,D_max],[D_min,D_max],"--",color="k",lw=1)
# ax.plot(df_train["D_exp"],mean_train,"o",label="Train") # Linear fit
# ax.plot(df_test["D_exp"],mean_test,"o",label="Test") # Linear fit
ax.plot(df_train["D_exp"],np.exp(mean_train),"o",label="Train") # Log fit
ax.plot(df_test["D_exp"],np.exp(mean_test),"o",label="Test") # Log fit
ax.set_xscale("log")
ax.set_yscale("log")
ax.set_xlim(D_min,D_max)
ax.set_ylim(D_min,D_max)
ax.set_aspect("equal")
ax.set_xlabel("D_exp")
ax.set_ylabel("D_model")
ax.legend()
plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 104 calls to <function NeuralKernelNetwork._K at 0x1528b5351620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 6 calls to <function NeuralKernelNetwork._K_diag at 0x1528a9d85300> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# MSLE= 0.06990381471305786 , R^2= -1.2309396507800505

# %%
fig = plt.figure(figsize=(12,6))
fig.suptitle("D_exp")
nl=3; nc=4; i=0
for l in range(nl):
    for c in range(nc):
        ax = fig.add_subplot(nl,nc,1+i)
        ax.plot(df_train.iloc[:,i],df_train["D_exp"],"cx",label="Data(Train)")
        # ax.plot(df_test.iloc[:,i],df_test["D_exp"],"mx",label="Data(Test)")
        ax.plot(df_train.iloc[:,i],np.exp(mean_train),"b.",label="Pred(Train)")
        # ax.plot(df_test.iloc[:,i],np.exp(mean_test),"r.",label="Pred(Test)")
        ax.set_xlabel(df_train.columns[i])
        # ax.set_xscale("log")
        ax.set_yscale("log")
        if i==0:
            ax.legend()
        i=i+1
fig.tight_layout()
plt.show()

fig = plt.figure(figsize=(12,6))
fig.suptitle("D_exp")
nl=3; nc=4; i=0
for l in range(nl):
    for c in range(nc):
        ax = fig.add_subplot(nl,nc,1+i)
        # ax.plot(df_train.iloc[:,i],df_train["D_exp"],"cx",label="Data(Train)")
        ax.plot(df_test.iloc[:,i],df_test["D_exp"],"mx",label="Data(Test)")
        # ax.plot(df_train.iloc[:,i],np.exp(mean_train),"b.",label="Pred(Train)")
        ax.plot(df_test.iloc[:,i],np.exp(mean_test),"r.",label="Pred(Test)")
        ax.set_xlabel(df_train.columns[i])
        # ax.set_xscale("log")
        ax.set_yscale("log")
        if i==0:
            ax.legend()
        i=i+1
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Plot Figure 5

# %%
plt.style.use('../nature_style.txt')

fig=plt.figure(figsize=(5.9,5),dpi=600) # figsize=(width,height(inch)),dpi(dots per inch)

xlabels = [r"$R/L_n$", r"$R/L_{T_e}$", r"$R/L_{T_i}$", r"$n_i/n_e$", r"$T_e/T_i$", r"$\beta$", r"$\nu_{ee}$", r"$q_0$", r"$\hat{s}$", r"$\epsilon$", r"$\kappa$", r"$\delta$"]
text = ["(a)", "(b)", "(c)", "(d)", "(e)", "(f)", "(g)", "(h)", "(i)", "(j)", "(k)", "(l)"]
# fig.suptitle("D_exp")
nl=4; nc=3; i=0
D_min = 0.01 #df["D_exp"].min()
D_max = 20 #df["D_exp"].max()
for l in range(nl):
    for c in range(nc):
        ax = fig.add_subplot(nl,nc,1+i)
        # ax.plot(df.iloc[:,i],df["D_exp"],"x",label="All data")
        ax.plot(df_train.iloc[:,i],df_train["D_exp"],"g+",lw=1,label="Train")
        ax.plot(df_test.iloc[:,i],df_test["D_exp"],"bx",lw=1,label="Test")
        # ax.plot(np.array(df_test.iloc[:,i])[outliner_list[0]],np.array(df_test["D_exp"])[outliner_list[0]],"x",c="red",label="")
        # ax.plot(np.array(df_test.iloc[:,i])[outliner_list[1]],np.array(df_test["D_exp"])[outliner_list[1]],"*",c="red",label="")
        # ax.plot(np.array(df_test.iloc[:,i])[outliner_list[2]],np.array(df_test["D_exp"])[outliner_list[2]],"^",c="red",label="")
        # ax.plot(np.array(df_test.iloc[:,i])[outliner_list[3]],np.array(df_test["D_exp"])[outliner_list[3]],"s",c="red",label="Outliner")
        ax.set_xlabel(xlabels[i])
        # ax.set_xscale("log")
        ax.set_yscale("log")
        ax.set_ylim(D_min,D_max)
        if i==7 or i==9 or i==10:
            ax.text(0.05, 0.82,text[i],color="k", fontfamily="sans-serif", fontweight="bold", fontsize=8, transform=ax.transAxes)
        else:
            ax.text(0.835, 0.82,text[i],color="k", fontfamily="sans-serif", fontweight="bold", fontsize=8, transform=ax.transAxes)
        if c==0:
            ax.set_ylabel(r"$D_\mathrm{exp}$")
        if i==0:
            ax.legend()
        i=i+1
fig.tight_layout()
plt.savefig("fig5.pdf",dpi=600,bbox_inches="tight")
plt.show()

# %%
plt.style.use('../nature_style.txt')

fig=plt.figure(figsize=(5.9,3),dpi=600) # figsize=(width,height(inch)),dpi(dots per inch)

ax = fig.add_subplot(1,3,1)
D_min = 0.01 #df["D_exp"].min()
D_max = 20 #df["D_exp"].max()
ax.plot([D_min,D_max],[D_min,D_max],"--",color="k",lw=0.5)
ax.plot(D_model_eq6(param_eq6,df_train),df_train["D_exp"],"+",label="Train")
ax.plot(D_model_eq6(param_eq6,df_test),df_test["D_exp"],".",label="Test")
ax.set_xscale("log")
ax.set_yscale("log")
ax.set_xlim(D_min,D_max)
ax.set_ylim(D_min,D_max)
ax.set_aspect("equal")
ax.set_aspect("equal")
ax.set_xlabel(r"Prediction $D_\mathrm{QL}$")
ax.set_ylabel(r"Experimental $D_\mathrm{exp}$")
ax.legend(loc="lower right")
ax.text(0.015,9,"(a)",color="k", fontfamily="sans-serif", fontweight="bold", fontsize=8)

ax = fig.add_subplot(1,3,2)
D_min = 0.01 #df["D_exp"].min()
D_max = 20 #df["D_exp"].max()
ax.plot([D_min,D_max],[D_min,D_max],"--",color="k",lw=0.5)
ax.plot(np.exp(mean_train_1),df_train["D_exp"],"+",label="Train")
ax.plot(np.exp(mean_test_1),df_test["D_exp"],".",label="Test")
# outliner_list = [18,84,44,17]
# ax.plot(np.exp(mean_test_1)[outliner_list[0]],np.array(df_test["D_exp"])[outliner_list[0]],"x",c="red",label="")
# ax.plot(np.exp(mean_test_1)[outliner_list[1]],np.array(df_test["D_exp"])[outliner_list[1]],"*",c="red",label="")
# ax.plot(np.exp(mean_test_1)[outliner_list[2]],np.array(df_test["D_exp"])[outliner_list[2]],"^",c="red",label="")
# ax.plot(np.exp(mean_test_1)[outliner_list[3]],np.array(df_test["D_exp"])[outliner_list[3]],"s",c="red",label="Outliner")
ax.set_xscale("log")
ax.set_yscale("log")
ax.set_xlim(D_min,D_max)
ax.set_ylim(D_min,D_max)
ax.set_aspect("equal")
ax.set_aspect("equal")
ax.set_xlabel(r"Prediction $D_\mathrm{SingleGP}$")
ax.set_ylabel(r"Experimental $D_\mathrm{exp}$")
ax.legend(loc="lower right")
ax.text(0.015,9,"(b)",color="k", fontfamily="sans-serif", fontweight="bold", fontsize=8)

ax = fig.add_subplot(1,3,3)
D_min = 0.01 #df["D_exp"].min()
D_max = 20 #df["D_exp"].max()
ax.plot([D_min,D_max],[D_min,D_max],"--",color="k",lw=0.5)
ax.plot(np.exp(mean_train),df_train["D_exp"],"+",label="Train")
ax.plot(np.exp(mean_test),df_test["D_exp"],".",label="Test")
# ax.plot(np.exp(mean_test)[outliner_list[0]],np.array(df_test["D_exp"])[outliner_list[0]],"x",c="red",label="")
# ax.plot(np.exp(mean_test)[outliner_list[1]],np.array(df_test["D_exp"])[outliner_list[1]],"*",c="red",label="")
# ax.plot(np.exp(mean_test)[outliner_list[2]],np.array(df_test["D_exp"])[outliner_list[2]],"^",c="red",label="")
# ax.plot(np.exp(mean_test)[outliner_list[3]],np.array(df_test["D_exp"])[outliner_list[3]],"s",c="red",label="Outliner")
ax.set_xscale("log")
ax.set_yscale("log")
ax.set_xlim(D_min,D_max)
ax.set_ylim(D_min,D_max)
ax.set_aspect("equal")
ax.set_aspect("equal")
ax.set_xlabel(r"Prediction $D_\mathrm{NARGP}$")
ax.set_ylabel(r"Experimental $D_\mathrm{exp}$")
ax.legend(loc="lower right")
ax.text(0.015,9,"(c)",color="k", fontfamily="sans-serif", fontweight="bold", fontsize=8)

plt.tight_layout()
plt.savefig("fig6.pdf",dpi=600,bbox_inches="tight")
plt.show()

# %%
from scipy.spatial import distance
# test_points = np.array(df_test.iloc[:,0:12])
# train_points = np.array(df_train.iloc[:,0:12])
# all_points = np.array(df.iloc[:,0:12])
test_points = np.concatenate([df_test.iloc[:,0:12],df_test.iloc[:,19:20]],axis=1)
train_points = np.concatenate([df_train.iloc[:,0:12],df_train.iloc[:,19:20]],axis=1)
all_points = np.concatenate([df.iloc[:,0:12],df.iloc[:,19:20]],axis=1)
covariance_matrix = np.cov(all_points.T)
#inv_covariance_matrix = np.linalg.inv(covariance_matrix)
inv_covariance_matrix = np.linalg.pinv(covariance_matrix)

distances_of_test_from_train = np.array([distance.mahalanobis(x, y, inv_covariance_matrix)
                          for x in test_points for y in train_points])
print(test_points.shape,train_points.shape,distances_of_test_from_train.shape)
distances_of_test_from_train = distances_of_test_from_train.reshape(test_points.shape[0], len(train_points))
print(distances_of_test_from_train.shape)
min_distances_of_test_from_train_dataset = np.min(distances_of_test_from_train, axis=1)
print(min_distances_of_test_from_train_dataset.shape)

far_list = min_distances_of_test_from_train_dataset>2.8
near_list = min_distances_of_test_from_train_dataset<=2.8
print(far_list)
plt.plot(min_distances_of_test_from_train_dataset)
# plt.plot(outliner_list,min_distances_of_test_from_train_dataset[outliner_list],"o")
plt.plot(np.arange(len(far_list))[far_list],min_distances_of_test_from_train_dataset[far_list],"x",c="red")
plt.plot(np.arange(len(near_list))[near_list],min_distances_of_test_from_train_dataset[near_list],".",c="green")
plt.show()
# Out:
# (68, 13) (67, 13) (4556,)
# (68, 67)
# (68,)
# [ True False False False False  True False False False False False False
#   True False False False False False  True False False False False False
#  False  True False False False False False False False  True False False
#   True False False False False  True False False False False  True False
#  False  True False False  True False False False False False False  True
#  False False False False  True  True  True  True]

# %%
fig=plt.figure(figsize=(3,2.5))
ax=fig.add_subplot()
D_min = 0.01 #df["D_exp"].min()
D_max = 20 #df["D_exp"].max()
ax.plot([D_min,D_max],[D_min,D_max],"--",color="k",lw=0.5)
ax.plot(np.exp(mean_train_1),df_train["D_exp"],"+",label="Train")
# ax.plot(np.exp(mean_test_1),df_test["D_exp"],".",label="Test")
ax.plot(np.exp(mean_test)[far_list],np.array(df_test["D_exp"])[far_list],"x",c="red",label="Test (far from train)")
ax.plot(np.exp(mean_test)[near_list],np.array(df_test["D_exp"])[near_list],".",c="green",label="Test (near from train)")
ax.set_xscale("log")
ax.set_yscale("log")
ax.set_xlim(D_min,D_max)
ax.set_ylim(D_min,D_max)
ax.set_aspect("equal")
ax.set_aspect("equal")
ax.set_xlabel(r"Prediction $D_\mathrm{SingleGP}$")
ax.set_ylabel(r"Experimental $D_\mathrm{exp}$")
ax.legend(loc="lower right")
fig.savefig("Mah.pdf")
plt.show()

# %%
fig=plt.figure(figsize=(3,2.5),dpi=150)
plt.plot(min_distances_of_test_from_train_dataset[far_list],(np.log(1+np.exp(mean_test)[far_list,0])-np.log(1+np.array(df_test["D_exp"])[far_list]))**2,"x",c="red")
plt.plot(min_distances_of_test_from_train_dataset[near_list],(np.log(1+np.exp(mean_test)[near_list,0])-np.log(1+np.array(df_test["D_exp"])[near_list]))**2,".",c="green")
plt.xlabel("Mahalanobis distance")
plt.xlim(0,None)
plt.axhline(0,c="k",lw=0.5)
plt.ylabel("Squared logarithmic error \n"+r"$[\ln(1+D_\mathrm{exp})-\ln(1+D_\mathrm{pred})]^2$")
plt.show()

# %%
plt.plot(min_distances_of_test_from_train_dataset[far_list],np.exp(mean_test)[far_list,0]-np.array(df_test["D_exp"])[far_list],"x",c="red")
plt.plot(min_distances_of_test_from_train_dataset[near_list],np.exp(mean_test)[near_list,0]-np.array(df_test["D_exp"])[near_list],".",c="green")
plt.show()
